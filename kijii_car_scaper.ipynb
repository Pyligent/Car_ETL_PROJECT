# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup 

import datetime
import re

import pandas as pd

# %% [markdown]
# # Extraction
#
# ## Extract all listing car information in GTA area from kijiji webite
#
# ### Key Car information is as below:
#
# - 'brand'
# - 'model'
# - 'model_year'
# - 'list_price'
# - 'color'
# - 'configration'
# - 'condition'
# - 'body_type'
# - 'wheel_config'
# - 'transmission'
# - 'fuel_type'
# - 'mileage'
# - 'carfax_link'
# - 'dealer_address'
#
# #### Examples:
# Car Information link: https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2009-ford-f-150-xlt-super-crew-4x4/1385290163
#
# - brand :'Ford'
# - model:'F-150'
# - model_year:'2009'
# - list_price: '$11,999.00'
# - color: 'Blue'
# - configration: 'XLT'
# - condition: 'Used'
# - body_type: 'Pickup Truck'
# - wheel_config: '4 x 4'
# - transmission: 'Automatic'
# - fuel_type:  'Gasoline'
# - mileage: '204,000'
# - carfax_link: 'https://www.carproof.com/order?ref=kijiji&vin=1FTRW14819FB42024'
# - dealer_address: '2 Castleton Ave unit 3, York, ON, M6N 3Z5'

# %%
def get_page_num(url):
    
    html = urlopen(url)
    bs = BeautifulSoup(html, 'html.parser')
    try:
        page_info = bs.find('div',class_='showing').text
        page_num = page_info.split()[-2].replace(',','')
        page_num = int(int(page_num)/20)
    except:
        page_num = 1
        pass
    
    return page_num

# %%
def get_item_info(url):
    item_info_list = []
   
        
    html = urlopen(url)
    bs_item = BeautifulSoup(html, 'html.parser')
    
    try: 
        item_brand = bs_item.find(itemprop='brand').text
    except:
        item_brand ='na'
    
    
    try:
        item_model = bs_item.find(itemprop='model').text
    except:
        item_model ='na'
    
    try:
        item_date = bs_item.find(itemprop='vehicleModelDate').text
    except:
        item_date ='na'
    
    try:
        item_price = bs_item.find('span',itemprop='price').text
    except:
        item_price = 'na'
    
    try:
        item_color = bs_item.find(itemprop='color').text
    except:
        item_color = 'na'
        
    try:
        item_config = bs_item.find(itemprop='vehicleConfiguration').text
    except:
        item_config = 'na'
    
    try:
        item_condition = bs_item.find(itemprop='itemCondition').text
    except:
        item_condition = 'na'
    
    try:
        item_bodytype = bs_item.find(itemprop='bodyType').text
    except:
        item_bodytype = 'na'
        
    try:
        item_wheelConfig = bs_item.find(itemprop='driveWheelConfiguration').text
    except:
        item_wheelConfig = 'na'
        
    try:
        item_transmission = bs_item.find(itemprop='vehicleTransmission').text
    except:
        item_transmission = 'na'
        
    try:
        item_fueltype = bs_item.find(itemprop='fuelType').text
    except:
        item_fueltype = 'na'
        
    try:
        item_mileage = bs_item.find(itemprop='mileageFromOdometer').text
    except:
        item_mileage = 'na'
    
       
    item_carfax = bs_item.find('a', href=re.compile('^(https://reports.carproof.com)((?!:).)*$'))
    try:
        item_carfax_link = item_carfax.attrs['href']
    except:
        item_carfax = bs_item.find('a', href=re.compile('^(https://www.carproof.com)((?!:).)*$'))
        try: 
            item_carfax_link = item_carfax.attrs['href']
        except:
            item_carfax_link = 'na'
    
        
    try:
        item_dealer_add = bs_item.find(itemprop='address').text
    except:
        item_dealer_add = 'na'
    
   
        

    
    item_info_list.append(item_brand)
    item_info_list.append(item_model)
    item_info_list.append(item_date)
    item_info_list.append(item_price)
    item_info_list.append(item_color)
    item_info_list.append(item_config)
    item_info_list.append(item_condition)
    item_info_list.append(item_bodytype)
    item_info_list.append(item_wheelConfig)
    item_info_list.append(item_transmission)
    item_info_list.append(item_fueltype)
    item_info_list.append(item_mileage)
    item_info_list.append(item_carfax_link)
    item_info_list.append(item_dealer_add)
   
    
    return item_info_list

# %%
title=[]
price=[]
itemurl=[]

base_url = 'https://www.kijiji.ca'
init_url = 'https://www.kijiji.ca/b-cars-vehicles/city-of-toronto/c27l1700273'

page_num = get_page_num(init_url)

page_num
# Out:
# 5008

# %%
all_info_list = []
itemlist = []
for page in range(1,page_num):
    page_url = 'https://www.kijiji.ca/b-cars-vehicles/city-of-toronto/'+'page+'+ str(page)+'/c27l1700273'
    html = urlopen(page_url)
    bs = BeautifulSoup(html, 'html.parser')
    for link in bs.find_all('a', href=re.compile('^(/v-cars-trucks/)((?!:).)*$')):
        if 'href' in link.attrs:
            item_url = base_url + link.attrs['href']
            if '?' not in item_url:
                print(item_url)
                itemlist = get_item_info(item_url)
                print(itemlist)
                all_info_list.append(itemlist)
                itemlist = []
# Out:
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-silverado-lt-4x4-navi-leather-3-year-warranty/1401107439
# ['Chevrolet', 'Silverado 1500', '2017', '$30,999.99', 'Black', 'LT', 'Used', 'Pickup Truck', '4 x 4', 'Automatic', 'Gasoline', '115,000', 'https://www.carproof.com/order?ref=kijiji&vin=3GCUKRECXHG233474', 'Brydon Drive, Etobicoke, ON']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-volkswagen-tiguan-comfortline-4wd/1386690847
# ['Volkswagen', 'Tiguan', '2013', '$11,450.00', 'Grey', 'COMFORTLINE  4WD', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '129,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', '1205 Finch Avenue West, Toronto, ON, M3J 2E8']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-gmc-acadia-slt-2/1402706481
# ['GMC', 'Acadia', '2017', '$33,988.00', 'Other', 'SLT-2', 'Used', 'Other', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '73,893', 'https://reports.carproof.com/en/main?id=ioaVnMDRqWSUYvSqQx36orRln0cVjAqC&utm_ref=kijiji', '1900 Victoria Park Avenue, Toronto, ON, M1R 1T6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/cash-money-for-ur-scrap-cars-used-cars-6478381409/1252548629
# ['Acura', 'TL', '2002', '$500.00', 'na', 'na', 'Used', 'Sedan', 'na', 'na', 'na', '200,500', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M5N1A1']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-honda-accord-sedan-lx-no-accidents-backup-cam-heated-seats/1410012732
# ['Honda', 'Accord', '2015', '$15,499.00', 'White', 'LX', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '93,000', 'https://www.carproof.com/order?ref=kijiji&vin=1HGCR2F36FA803335', '1726 Kingston Road, Scarborough, ON, M1N 1S8']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-low-kms-pontiac-montana-for-sale/1410151452
# ['Pontiac', 'Montana', '2006', '$1,100.00', 'Silver', 'na', 'Used', 'SUV, Crossover', 'na', 'Automatic', 'Gasoline', '147,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Norman Ross Dr, Markham, ON L3S 3E8, Canada']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2011-chrysler-300-limited-loaded-leather-e-tested/1410151234
# ['Chrysler', '300-Series', '2011', '$3,400.00', 'Black', 'LIMITED', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '176,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9C 1G5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-malibu-ltleather-navi-panoroof/1410151007
# ['Chevrolet', 'Malibu', '2017', '$19,999.00', 'Blue', 'LTLEATHER|NAVI|PANOROOF|', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '41,432', 'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990', '2701 Derry Rd. E, Mississauga, ON, L4T 1A2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-honda-civic-sedan-lx-certified/1410150265
# ['Honda', 'Civic', '2017', '$11,971.00', 'White', 'LX', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '21,196', 'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405', '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-porsche-cayenne/1410150278
# ['Porsche', 'Cayenne', '2013', 'na', 'White', 'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '154,000', 'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831', '46 Milvan Drive, Toronto, ON, M9L 1Z3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-toyota-corolla-ce/1410150845
# ['Toyota', 'Corolla', '2006', '$2,600.00', 'na', 'na', 'Used', 'Sedan', 'na', 'Automatic', 'na', '226', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M4B2E5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-ford-escape-se-62-wk-heated-seat-alloys-backup-camera/1385281347
# ['Ford', 'Escape', '2015', '$15,988.00', 'White', 'SE, $62/wk, heated seat, alloys, backup camera', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'Gasoline', '74,899', 'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026', '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2001-cadillac-dhs/1410150459
# ['Cadillac', 'DeVille', '2001', '$1,000.00', 'Burgundy', 'DHS', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '200,000', 'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388', 'Woodbridge, ON L4L 8L6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2018-ford-edge-1-owner-accident-free-navi-heated-seats-awd/1405140164
# ['Ford', 'Edge', '2018', '$43,578.00', 'Silver', '1 OWNER, Accident Free, Navi, Heated Seats, AWD', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '11,618', 'https://www.carproof.com/order?ref=kijiji&vin=2FMPK4AP1JBB18212', '2595 Saint Clair Avenue West, Toronto, ON, M6N 4Z5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2012-toyota-camry-hybrid-le/1410150052
# ['Toyota', 'Other', '2012', '$11,500.00', 'na', 'LE', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Hybrid-Electric', '156,988', 'https://www.carproof.com/order?ref=kijiji&vin=4T1BD1FK6CU022427', 'Toronto, ON M1X0B1']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2014-bmw-3-series-320i-x-drive-sport-navi-pkg-aut0-sunroof-103k/1368744520
# ['BMW', '3-Series', '2014', '$21,500.00', 'Red', '320I X DRIVE SPORT+ NAVI PKG AUT0 SUNROOF 103K', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '103,558', 'https://www.carproof.com/order?ref=kijiji&vin=WBA3C3C57EP661923', '1235 Finch Ave. W., Toronto, ON, M3J 2G4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-tesla-model-s-p85d-autopilot-21whls-sunroof-insane-mode/1404285926
# ['Tesla', 'na', '2015', '$93,995.00', 'Blue', 'Autopilot, 21Whls, Sunroof, INSANE Mode, EV', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Hybrid-Electric', '27,981', 'https://reports.carproof.com/en/main?id=ig5IdGR Tn7AKuTK3l D0/dbTFYkLIFw&utm_ref=kijiji', '212 Lakeshore Road West, Mississauga, ON, L5H 1G6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2014-toyota-rav4-le-awd/1408678874
# ['Toyota', 'RAV4', '2014', '$15,950.00', 'Grey', 'LE AWD', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'na', '131,000', 'https://reports.carproof.com/en/main?id=DCWc4i5kYytt1E0PJOoumZeukle/VlgJ&utm_ref=kijiji', '1205 Finch Avenue West, Toronto, ON, M3J 2E8']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2016-honda-civic-ex-t-w-honda-sensing-sunroof-rear-camera/1400176634
# ['Honda', 'Civic', '2016', '$21,877.00', 'White', 'EX-T w/Honda Sensing/SUNROOF/REAR CAMERA !!!', 'Used', 'Coupe (2 door)', 'Front-wheel drive (FWD)', 'Automatic', 'na', '30,345', 'https://www.carproof.com/order?ref=kijiji&vin=2HGFC3B42GH425293', '2685 Highway 7 West, Concord, ON, L4K 1V8']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-low-kms-pontiac-montana-for-sale/1410151452
# ['Pontiac', 'Montana', '2006', '$1,100.00', 'Silver', 'na', 'Used', 'SUV, Crossover', 'na', 'Automatic', 'Gasoline', '147,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Norman Ross Dr, Markham, ON L3S 3E8, Canada']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2011-chrysler-300-limited-loaded-leather-e-tested/1410151234
# ['Chrysler', '300-Series', '2011', '$3,400.00', 'Black', 'LIMITED', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '176,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9C 1G5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-malibu-ltleather-navi-panoroof/1410151007
# ['Chevrolet', 'Malibu', '2017', '$19,999.00', 'Blue', 'LTLEATHER|NAVI|PANOROOF|', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '41,432', 'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990', '2701 Derry Rd. E, Mississauga, ON, L4T 1A2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-honda-civic-sedan-lx-certified/1410150265
# ['Honda', 'Civic', '2017', '$11,971.00', 'White', 'LX', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '21,196', 'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405', '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-porsche-cayenne/1410150278
# ['Porsche', 'Cayenne', '2013', 'na', 'White', 'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '154,000', 'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831', '46 Milvan Drive, Toronto, ON, M9L 1Z3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-toyota-corolla-ce/1410150845
# ['Toyota', 'Corolla', '2006', '$2,600.00', 'na', 'na', 'Used', 'Sedan', 'na', 'Automatic', 'na', '226', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M4B2E5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-ford-escape-se-62-wk-heated-seat-alloys-backup-camera/1385281347
# ['Ford', 'Escape', '2015', '$15,988.00', 'White', 'SE, $62/wk, heated seat, alloys, backup camera', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'Gasoline', '74,899', 'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026', '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2001-cadillac-dhs/1410150459
# ['Cadillac', 'DeVille', '2001', '$1,000.00', 'Burgundy', 'DHS', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '200,000', 'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388', 'Woodbridge, ON L4L 8L6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2014-honda-accord-touring-navigation-leather-sunroof-back-up-cam/1405059341
# ['Honda', 'Accord', '2014', '$16,950.00', 'Grey', 'TOURING NAVIGATION LEATHER SUNROOF BACK UP CAMERA', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '123,000', 'https://reports.carproof.com/en/main?id=34OnNI4CMaISU IE/u9OXBCX6HCa7d1T&utm_ref=kijiji', '1205 Finch Avenue West, Toronto, ON, M3J 2E8']
# https://www.kijiji.ca/v-cars-trucks/peterborough/2006-honda-jazz-like-new/1363126190
# ['Honda', 'Other', '2006', '$1,190.00', 'Red', 'LIKE NEW!!/CHRISTMAS SPECIAL!!', 'Used', 'Sedan', 'Other', 'Other', 'Gasoline', '513', 'https://www.carproof.com/order?ref=kijiji&vin=JH2AF60296K400313', '4 Harvest Street, Lindsay, ON, K9V 4W9']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-porsche-cayenne-gts-nav-porsche-entry-drive-lane-change-ass/1394849945
# ['Porsche', 'Cayenne', '2013', '$53,988.00', 'White', 'GTS/NAV/PORSCHE ENTRY&DRIVE/LANE CHANGE ASSIST', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'na', '69,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', '46 Milvan Drive, Toronto, ON, M9L 1Z3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2012-audi-s4-3-0t-quattro-prem-n/1379076257
# ['Audi', 'S4', '2012', '$21,800.00', 'Black', '3.0T QUATTRO PREM, N', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'na', '114,208', 'https://www.carproof.com/order?ref=kijiji&vin=WAUBGCFL5CA111274', '60 Martin Ross Avenue, Toronto, ON, M3J 2L4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2012-bmw-x5-drive-35i-m-sport-activity-premium-pkg/1384930964
# ['BMW', 'X5', '2012', '$20,500.00', 'White', 'X DRIVE 35i M SPORT + ACTIVITY + PREMIUM PKG', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '147,168', 'https://www.carproof.com/order?ref=kijiji&vin=5UXZV4C50CL746845', '1235 Finch Ave. W., Toronto, ON, M3J 2G4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-low-kms-pontiac-montana-for-sale/1410151452
# ['Pontiac', 'Montana', '2006', '$1,100.00', 'Silver', 'na', 'Used', 'SUV, Crossover', 'na', 'Automatic', 'Gasoline', '147,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Norman Ross Dr, Markham, ON L3S 3E8, Canada']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2011-chrysler-300-limited-loaded-leather-e-tested/1410151234
# ['Chrysler', '300-Series', '2011', '$3,400.00', 'Black', 'LIMITED', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '176,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9C 1G5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-malibu-ltleather-navi-panoroof/1410151007
# ['Chevrolet', 'Malibu', '2017', '$19,999.00', 'Blue', 'LTLEATHER|NAVI|PANOROOF|', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '41,432', 'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990', '2701 Derry Rd. E, Mississauga, ON, L4T 1A2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-honda-civic-sedan-lx-certified/1410150265
# ['Honda', 'Civic', '2017', '$11,971.00', 'White', 'LX', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '21,196', 'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405', '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-porsche-cayenne/1410150278
# ['Porsche', 'Cayenne', '2013', 'na', 'White', 'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '154,000', 'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831', '46 Milvan Drive, Toronto, ON, M9L 1Z3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-toyota-corolla-ce/1410150845
# ['Toyota', 'Corolla', '2006', '$2,600.00', 'na', 'na', 'Used', 'Sedan', 'na', 'Automatic', 'na', '226', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M4B2E5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-ford-escape-se-62-wk-heated-seat-alloys-backup-camera/1385281347
# ['Ford', 'Escape', '2015', '$15,988.00', 'White', 'SE, $62/wk, heated seat, alloys, backup camera', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'Gasoline', '74,899', 'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026', '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2001-cadillac-dhs/1410150459
# ['Cadillac', 'DeVille', '2001', '$1,000.00', 'Burgundy', 'DHS', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '200,000', 'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388', 'Woodbridge, ON L4L 8L6']
# https://www.kijiji.ca/v-cars-trucks/ottawa/2008-toyota-yaris-sedan/1403025735
# ['Toyota', 'Yaris', '2008', '$4,995.00', 'Blue', 'sedan', 'Used', 'Sedan', 'Other', 'Automatic', 'Gasoline', '140,373', 'https://www.carproof.com/order?ref=kijiji&vin=JTDBT923X81226449', '1037 Belfast Road, Ottawa, ON, K1B 3S2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-volkswagen-jetta-2-0l-trendline-5-speed-a-c-h-seats-rear-ca/1405388778
# ['Volkswagen', 'Jetta', '2015', '$9,500.00', 'White', '2.0L TRENDLINE 5 SPEED A/C H/SEATS REAR CAMERA 67K', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Manual', 'na', '67,069', 'https://reports.carproof.com/en/main?id=IwjEf/IknJjv3y6vUsaQogmqQHyEVIGQ&utm_ref=kijiji', '1235 Finch Ave. W., Toronto, ON, M3J 2G4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2014-bmw-5-series-535d-xdrive-navi-m/1374258940
# ['BMW', '5-Series', '2014', '$32,800.00', 'Black', '535d xDrive, NAVI, M', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'na', '78,690', 'https://www.carproof.com/order?ref=kijiji&vin=WBAFV3C57ED684353', '60 Martin Ross Avenue, Toronto, ON, M3J 2L4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-low-kms-pontiac-montana-for-sale/1410151452
# ['Pontiac', 'Montana', '2006', '$1,100.00', 'Silver', 'na', 'Used', 'SUV, Crossover', 'na', 'Automatic', 'Gasoline', '147,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Norman Ross Dr, Markham, ON L3S 3E8, Canada']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2011-chrysler-300-limited-loaded-leather-e-tested/1410151234
# ['Chrysler', '300-Series', '2011', '$3,400.00', 'Black', 'LIMITED', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '176,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9C 1G5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-malibu-ltleather-navi-panoroof/1410151007
# ['Chevrolet', 'Malibu', '2017', '$19,999.00', 'Blue', 'LTLEATHER|NAVI|PANOROOF|', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '41,432', 'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990', '2701 Derry Rd. E, Mississauga, ON, L4T 1A2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-honda-civic-sedan-lx-certified/1410150265
# ['Honda', 'Civic', '2017', '$11,971.00', 'White', 'LX', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '21,196', 'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405', '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-porsche-cayenne/1410150278
# ['Porsche', 'Cayenne', '2013', 'na', 'White', 'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '154,000', 'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831', '46 Milvan Drive, Toronto, ON, M9L 1Z3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-toyota-corolla-ce/1410150845
# ['Toyota', 'Corolla', '2006', '$2,600.00', 'na', 'na', 'Used', 'Sedan', 'na', 'Automatic', 'na', '226', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M4B2E5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-ford-escape-se-62-wk-heated-seat-alloys-backup-camera/1385281347
# ['Ford', 'Escape', '2015', '$15,988.00', 'White', 'SE, $62/wk, heated seat, alloys, backup camera', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'Gasoline', '74,899', 'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026', '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2001-cadillac-dhs/1410150459
# ['Cadillac', 'DeVille', '2001', '$1,000.00', 'Burgundy', 'DHS', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '200,000', 'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388', 'Woodbridge, ON L4L 8L6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-hyundai-elantra-gls-sunroof-alloys-back-up-camera/1405059361
# ['Hyundai', 'Elantra', '2017', '$14,850.00', 'Red', 'GLS SUNROOF ALLOYS BACK UP CAMERA', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '103,000', 'https://reports.carproof.com/en/main?id=VRTtr/bu8HcxWy1UVsqM08CgyGVqEC21&utm_ref=kijiji', '1205 Finch Avenue West, Toronto, ON, M3J 2E8']
# https://www.kijiji.ca/v-cars-trucks/kitchener-waterloo/2019-hyundai-santa-fe-ultimate/1408979113
# ['Hyundai', 'Santa Fe', '2019', 'na', 'Silver', 'Ultimate', 'New', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'na', 'na', 'na', '1962 Eagle Street North, Cambridge, ON, N3H 0A1']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2008-mercedes-s550-lwb-black-on-tan-amg-package-4matic-150km/1407234713
# ['Mercedes-Benz', 'S-Class', '2008', '$19,000.00', 'Black', 'S550', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '150,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Scarborough, ON M1L 4S2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-volkswagen-passat-1-8-tsi-highline-navigation-leather-sunro/1408617202
# ['Volkswagen', 'Passat', '2015', '$15,950.00', 'White', '1.8 TSI HIGHLINE NAVIGATION LEATHER SUNROOF', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '126,000', 'https://reports.carproof.com/en/main?id=7jXAgPYG7tt7JYcucHoV2fzGgWauR3H9&utm_ref=kijiji', '1205 Finch Avenue West, Toronto, ON, M3J 2E8']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-low-kms-pontiac-montana-for-sale/1410151452
# ['Pontiac', 'Montana', '2006', '$1,100.00', 'Silver', 'na', 'Used', 'SUV, Crossover', 'na', 'Automatic', 'Gasoline', '147,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Norman Ross Dr, Markham, ON L3S 3E8, Canada']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2011-chrysler-300-limited-loaded-leather-e-tested/1410151234
# ['Chrysler', '300-Series', '2011', '$3,400.00', 'Black', 'LIMITED', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '176,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9C 1G5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-malibu-ltleather-navi-panoroof/1410151007
# ['Chevrolet', 'Malibu', '2017', '$19,999.00', 'Blue', 'LTLEATHER|NAVI|PANOROOF|', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '41,432', 'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990', '2701 Derry Rd. E, Mississauga, ON, L4T 1A2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-honda-civic-sedan-lx-certified/1410150265
# ['Honda', 'Civic', '2017', '$11,971.00', 'White', 'LX', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '21,196', 'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405', '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-porsche-cayenne/1410150278
# ['Porsche', 'Cayenne', '2013', 'na', 'White', 'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '154,000', 'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831', '46 Milvan Drive, Toronto, ON, M9L 1Z3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-toyota-corolla-ce/1410150845
# ['Toyota', 'Corolla', '2006', '$2,600.00', 'na', 'na', 'Used', 'Sedan', 'na', 'Automatic', 'na', '226', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M4B2E5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-ford-escape-se-62-wk-heated-seat-alloys-backup-camera/1385281347
# ['Ford', 'Escape', '2015', '$15,988.00', 'White', 'SE, $62/wk, heated seat, alloys, backup camera', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'Gasoline', '74,899', 'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026', '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2001-cadillac-dhs/1410150459
# ['Cadillac', 'DeVille', '2001', '$1,000.00', 'Burgundy', 'DHS', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '200,000', 'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388', 'Woodbridge, ON L4L 8L6']
# https://www.kijiji.ca/v-cars-trucks/mississauga-peel-region/2015-honda-accord-sedan-sport-sunroof-rear-camera-heated/1409864371
# ['Honda', 'Accord', '2015', '$17,500.00', 'Black', 'Sport  | Sunroof | Rear Camera | Heated Seats', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '106,501', 'https://reports.carproof.com/en/main?id=QYMD5ev6wfpAtxy1p1VdZFI56G3AUtQ0&utm_ref=kijiji', '430 Hensall Cir, Mississauga, ON, L5A 1X7']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-honda-civic-sedan-ex-auto-sunroof-camera-only-85km/1408950763
# ['Honda', 'Civic', '2015', '$13,980.00', 'White', 'EX-AUTO-SUNROOF-CAMERA-ONLY 85KM', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '85,000', 'https://www.carproof.com/order?ref=kijiji&vin=2HGFB2F5XFH013248', '301 Weston Road, Toronto, ON, M6N3P1']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2012-infiniti-fx35-navigation-limited-edition/1367894676
# ['Infiniti', 'FX', '2012', '$20,950.00', 'Black', 'Limited Edition', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '140,000', 'https://www.carproof.com/order?ref=kijiji&vin=JN8AS1MW3CM153511', '11 Saint Regis Crescent North, North York, ON, M3J 1Y9']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2014-mazda-mazda3-gx-model-skyactiv/1393044988
# ['Mazda', 'Mazda3', '2014', '$10,400.00', 'Black', 'GX MODEL, SKYACTIV', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Manual', 'Gasoline', '67,800', 'https://www.carproof.com/order?ref=kijiji&vin=3MZBM1U7XEM122618', '3675 Keele Street, Toronto, ON, M3J 1M6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-low-kms-pontiac-montana-for-sale/1410151452
# ['Pontiac', 'Montana', '2006', '$1,100.00', 'Silver', 'na', 'Used', 'SUV, Crossover', 'na', 'Automatic', 'Gasoline', '147,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Norman Ross Dr, Markham, ON L3S 3E8, Canada']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2011-chrysler-300-limited-loaded-leather-e-tested/1410151234
# ['Chrysler', '300-Series', '2011', '$3,400.00', 'Black', 'LIMITED', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '176,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9C 1G5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-malibu-ltleather-navi-panoroof/1410151007
# ['Chevrolet', 'Malibu', '2017', '$19,999.00', 'Blue', 'LTLEATHER|NAVI|PANOROOF|', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '41,432', 'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990', '2701 Derry Rd. E, Mississauga, ON, L4T 1A2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-honda-civic-sedan-lx-certified/1410150265
# ['Honda', 'Civic', '2017', '$11,971.00', 'White', 'LX', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '21,196', 'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405', '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-porsche-cayenne/1410150278
# ['Porsche', 'Cayenne', '2013', 'na', 'White', 'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '154,000', 'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831', '46 Milvan Drive, Toronto, ON, M9L 1Z3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-toyota-corolla-ce/1410150845
# ['Toyota', 'Corolla', '2006', '$2,600.00', 'na', 'na', 'Used', 'Sedan', 'na', 'Automatic', 'na', '226', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M4B2E5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-ford-escape-se-62-wk-heated-seat-alloys-backup-camera/1385281347
# ['Ford', 'Escape', '2015', '$15,988.00', 'White', 'SE, $62/wk, heated seat, alloys, backup camera', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'Gasoline', '74,899', 'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026', '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2001-cadillac-dhs/1410150459
# ['Cadillac', 'DeVille', '2001', '$1,000.00', 'Burgundy', 'DHS', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '200,000', 'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388', 'Woodbridge, ON L4L 8L6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-bmw-328i-luxury-navi-rear-cam-x-drive/1392639339
# ['BMW', 'Other', '2015', '$23,799.00', 'Grey', 'LUXURY|NAVI|REAR CAM|X-DRIVE', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '74,000', 'https://www.carproof.com/order?ref=kijiji&vin=WBA3B3G52FNR87199', '150 Deerhide Crescent, North York, ON, M9M 2Y6']
# https://www.kijiji.ca/v-cars-trucks/mississauga-peel-region/2015-ford-edge-sel-awd-trade-in/1408461852
# ['Ford', 'Edge', '2015', '$23,495.00', 'Black', 'SEL | AWD | TRADE-IN |', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'na', '74,496', 'https://reports.carproof.com/en/main?id=CAqdOt0UM3B9lVuJfZJeoaSefEQ3JZ Y&utm_ref=kijiji', '190 Canam Crescent, Brampton, ON, L7A 1A9']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2014-mercedes-benz-cla-class-cla250-amg-sport-n/1388911992
# ['Mercedes-Benz', 'Other', '2014', '$23,800.00', 'White', 'CLA250, AMG SPORT, N', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '57,080', 'https://www.carproof.com/order?ref=kijiji&vin=WDDSJ4EB0EN134899', '60 Martin Ross Avenue, Toronto, ON, M3J 2L4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2016-audi-a6-2-0t-progressiv-awd-brown-leather-s-line-pkg/1377442780
# ['Audi', 'A6', '2016', '$36,388.00', 'White', '2.0T Progressiv | AWD | BROWN LEATHER | S-LINE PKG', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '26,188', 'https://www.carproof.com/order?ref=kijiji&vin=WAUJFAFC4GN053725', '354 Richmond St E, Toronto, ON, M5A 1P7']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2014-bmw-3-series-gran-turismo-328i-xdrive-navigation-panoramic/1379000985
# ['BMW', '3-Series', '2014', '$24,950.00', 'Black', '328i xDrive', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '66,000', 'https://www.carproof.com/order?ref=kijiji&vin=WBA3X5C5XED559212', '11 Saint Regis Crescent North, North York, ON, M3J 1Y9']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-low-kms-pontiac-montana-for-sale/1410151452
# ['Pontiac', 'Montana', '2006', '$1,100.00', 'Silver', 'na', 'Used', 'SUV, Crossover', 'na', 'Automatic', 'Gasoline', '147,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Norman Ross Dr, Markham, ON L3S 3E8, Canada']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2011-chrysler-300-limited-loaded-leather-e-tested/1410151234
# ['Chrysler', '300-Series', '2011', '$3,400.00', 'Black', 'LIMITED', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '176,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9C 1G5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-malibu-ltleather-navi-panoroof/1410151007
# ['Chevrolet', 'Malibu', '2017', '$19,999.00', 'Blue', 'LTLEATHER|NAVI|PANOROOF|', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '41,432', 'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990', '2701 Derry Rd. E, Mississauga, ON, L4T 1A2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-honda-civic-sedan-lx-certified/1410150265
# ['Honda', 'Civic', '2017', '$11,971.00', 'White', 'LX', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '21,196', 'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405', '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-porsche-cayenne/1410150278
# ['Porsche', 'Cayenne', '2013', 'na', 'White', 'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '154,000', 'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831', '46 Milvan Drive, Toronto, ON, M9L 1Z3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-toyota-corolla-ce/1410150845
# ['Toyota', 'Corolla', '2006', '$2,600.00', 'na', 'na', 'Used', 'Sedan', 'na', 'Automatic', 'na', '226', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M4B2E5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-ford-escape-se-62-wk-heated-seat-alloys-backup-camera/1385281347
# ['Ford', 'Escape', '2015', '$15,988.00', 'White', 'SE, $62/wk, heated seat, alloys, backup camera', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'Gasoline', '74,899', 'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026', '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2001-cadillac-dhs/1410150459
# ['Cadillac', 'DeVille', '2001', '$1,000.00', 'Burgundy', 'DHS', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '200,000', 'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388', 'Woodbridge, ON L4L 8L6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-acura-ilx-premium-pkg-leather-sunroof-back-up-camera/1405059325
# ['Acura', 'ILX', '2015', '$16,450.00', 'Black', 'PREMIUM PKG LEATHER SUNROOF BACK UP CAMERA', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '96,000', 'https://reports.carproof.com/en/main?id=QCZbdKW6IA0xcRZV2AVtrZxI8hjcSESc&utm_ref=kijiji', '1205 Finch Avenue West, Toronto, ON, M3J 2E8']
# https://www.kijiji.ca/v-cars-trucks/ottawa/2017-volkswagen-golf-r-2-0-tsi-leather-nav-blis/1354315606
# ['Volkswagen', 'Golf', '2017', '$34,950.00', 'White', '2.0 TSI LEATHER NAV 19ALLOYS WOW!!', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '40,250', 'https://www.carproof.com/order?ref=kijiji&vin=WVWVF7AUXHW013913', '880 Merivale Road, Ottawa, ON, K1Z 5Z6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chrysler-300-s-leather-all-wheel-drive-8-4-inch-touch-scree/1405233577
# ['Chrysler', '300-Series', '2017', '$24,677.00', 'Black', 'S LEATHER/ALL WHEEL DRIVE/8.4 INCH TOUCH SCREEN', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'na', '52,745', 'https://www.carproof.com/order?ref=kijiji&vin=2C3CCAGG8HH631541', '2685 Highway 7 West, Concord, ON, L4K 1V8']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-acura-mdx-elite-navi-dvd-360cam-ldws-lka-1-owner/1401042194
# ['Acura', 'MDX', '2017', '$46,995.00', 'Blue', 'ELITE|NAVI|DVD|360CAM|LDWS|LKA|1 OWNER', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '37,245', 'https://www.carproof.com/order?ref=kijiji&vin=5FRYD4H89HB504458', '2730 Markham Road, Scarborough, ON, M1X 1E6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-low-kms-pontiac-montana-for-sale/1410151452
# ['Pontiac', 'Montana', '2006', '$1,100.00', 'Silver', 'na', 'Used', 'SUV, Crossover', 'na', 'Automatic', 'Gasoline', '147,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Norman Ross Dr, Markham, ON L3S 3E8, Canada']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2011-chrysler-300-limited-loaded-leather-e-tested/1410151234
# ['Chrysler', '300-Series', '2011', '$3,400.00', 'Black', 'LIMITED', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '176,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9C 1G5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-malibu-ltleather-navi-panoroof/1410151007
# ['Chevrolet', 'Malibu', '2017', '$19,999.00', 'Blue', 'LTLEATHER|NAVI|PANOROOF|', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '41,432', 'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990', '2701 Derry Rd. E, Mississauga, ON, L4T 1A2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-honda-civic-sedan-lx-certified/1410150265
# ['Honda', 'Civic', '2017', '$11,971.00', 'White', 'LX', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '21,196', 'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405', '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-porsche-cayenne/1410150278
# ['Porsche', 'Cayenne', '2013', 'na', 'White', 'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '154,000', 'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831', '46 Milvan Drive, Toronto, ON, M9L 1Z3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-toyota-corolla-ce/1410150845
# ['Toyota', 'Corolla', '2006', '$2,600.00', 'na', 'na', 'Used', 'Sedan', 'na', 'Automatic', 'na', '226', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M4B2E5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-ford-escape-se-62-wk-heated-seat-alloys-backup-camera/1385281347
# ['Ford', 'Escape', '2015', '$15,988.00', 'White', 'SE, $62/wk, heated seat, alloys, backup camera', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'Gasoline', '74,899', 'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026', '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2001-cadillac-dhs/1410150459
# ['Cadillac', 'DeVille', '2001', '$1,000.00', 'Burgundy', 'DHS', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '200,000', 'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388', 'Woodbridge, ON L4L 8L6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-toyota-corolla-le-auto-camera-heated-seats-only-58km/1408191164
# ['Toyota', 'Corolla', '2017', '$14,999.00', 'Grey', 'LE-AUTO-CAMERA-HEATED SEATS-ONLY 58KM', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '58,000', 'https://www.carproof.com/order?ref=kijiji&vin=2T1BURHE5HC921407', '301 Weston Road, Toronto, ON, M6N3P1']
# https://www.kijiji.ca/v-cars-trucks/windsor-area-on/2013-chevrolet-equinox-lt-nav-back-up-cam-heated-seats/1388122372
# ['Chevrolet', 'Equinox', '2013', '$13,495.00', 'White', 'LT *Nav. Back up Cam. Heated Seats*', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '124,506', 'https://www.carproof.com/order?ref=kijiji&vin=2GNFLEEK5D6395306', '20600 County Rd 42 West, Tilbury, ON, N0P 2L0']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-volkswagen-tiguan-2-0tsi-trendline-aut0-a-c-h-seats-rear-ca/1408158477
# ['Volkswagen', 'Tiguan', '2015', '$14,990.00', 'Blue', '2.0TSI TRENDLINE AUT0 A/C H/SEATS REAR CAMERA 51K', 'Used', 'SUV, Crossover', 'Front-wheel drive (FWD)', 'Automatic', 'na', '51,628', 'https://reports.carproof.com/en/main?id=Vjk2rHVWZyluK7Bsin1enVoimD1kqUwI&utm_ref=kijiji', '1235 Finch Ave. W., Toronto, ON, M3J 2G4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2011-mercedes-benz-m-class-ml-350-bluetec/1394907960
# ['Mercedes-Benz', 'M-Class', '2011', '$17,988.00', 'Grey', 'DIESEL/NAV/KEYLESSGO/BACK-UP CAM/LOADED', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'na', '129,000', 'https://www.carproof.com/order?ref=kijiji&vin=4JGBB2FB2BA671961', '46 Milvan Drive, Toronto, ON, M9L 1Z3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2014-bmw-4-series-428i-navi-roof-xeonlights/1367425531
# ['BMW', '4-Series', '2014', '$22,999.00', 'Red', '428i|NAVI|ROOF|XEONLIGHTS|', 'Used', 'Coupe (2 door)', 'Rear-wheel drive (RWD)', 'Automatic', 'Gasoline', '86,758', 'https://www.carproof.com/order?ref=kijiji&vin=WBA3N3C50EF710878', '2701 Derry Rd. E, Mississauga, ON, L4T 1A2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-low-kms-pontiac-montana-for-sale/1410151452
# ['Pontiac', 'Montana', '2006', '$1,100.00', 'Silver', 'na', 'Used', 'SUV, Crossover', 'na', 'Automatic', 'Gasoline', '147,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Norman Ross Dr, Markham, ON L3S 3E8, Canada']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2011-chrysler-300-limited-loaded-leather-e-tested/1410151234
# ['Chrysler', '300-Series', '2011', '$3,400.00', 'Black', 'LIMITED', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '176,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9C 1G5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-malibu-ltleather-navi-panoroof/1410151007
# ['Chevrolet', 'Malibu', '2017', '$19,999.00', 'Blue', 'LTLEATHER|NAVI|PANOROOF|', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '41,432', 'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990', '2701 Derry Rd. E, Mississauga, ON, L4T 1A2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-honda-civic-sedan-lx-certified/1410150265
# ['Honda', 'Civic', '2017', '$11,971.00', 'White', 'LX', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '21,196', 'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405', '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-porsche-cayenne/1410150278
# ['Porsche', 'Cayenne', '2013', 'na', 'White', 'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '154,000', 'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831', '46 Milvan Drive, Toronto, ON, M9L 1Z3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-toyota-corolla-ce/1410150845
# ['Toyota', 'Corolla', '2006', '$2,600.00', 'na', 'na', 'Used', 'Sedan', 'na', 'Automatic', 'na', '226', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M4B2E5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-ford-escape-se-62-wk-heated-seat-alloys-backup-camera/1385281347
# ['Ford', 'Escape', '2015', '$15,988.00', 'White', 'SE, $62/wk, heated seat, alloys, backup camera', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'Gasoline', '74,899', 'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026', '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2001-cadillac-dhs/1410150459
# ['Cadillac', 'DeVille', '2001', '$1,000.00', 'Burgundy', 'DHS', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '200,000', 'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388', 'Woodbridge, ON L4L 8L6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2014-jeep-cherokee-limited-navigation-leather-awd/1405230377
# ['Jeep', 'Cherokee', '2014', '$17,950.00', 'Grey', 'LIMITED NAVIGATION LEATHER AWD', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'Gasoline', '116,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', '1205 Finch Avenue West, Toronto, ON, M3J 2E8']
# https://www.kijiji.ca/v-cars-trucks/oshawa-durham-region/2013-bmw-3-series-328i-xdrive/1383342177
# ['BMW', '3-Series', '2013', '$19,285.00', 'Brown', '328i xDrive', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '30,623', 'https://www.carproof.com/order?ref=kijiji&vin=WBA3B3C59DF539815', '55 Benson Court, Port Hope, ON, L1A 2M6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2014-audi-sq5-3-0t-quattro-technik/1383105045
# ['Audi', 'Q5', '2014', '$29,800.00', 'Black', '3.0T QUATTRO TECHNIK', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'na', '144,411', 'https://www.carproof.com/order?ref=kijiji&vin=WA1LGCFP7EA088393', '60 Martin Ross Avenue, Toronto, ON, M3J 2L4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2007-bmw-328i-convertible-navigation-only-121-000km-no-accident/1400279836
# ['BMW', '3-Series', '2007', '$9,995.00', 'Grey', '328i', 'Used', 'Convertible', 'Rear-wheel drive (RWD)', 'Automatic', 'Gasoline', '121,000', 'https://www.carproof.com/order?ref=kijiji&vin=WBAWL13507PX16944', '4490 Chesswood Drive Unit 2, Toronto, ON, M3J 2B9']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2010-maserati-gran-turismo-s-4-7-navi-park-se/1357380672
# ['Maserati', 'Gran Turismo', '2010', '$46,800.00', 'Black', 'S 4.7, NAVI, PARK SE', 'Used', 'Coupe (2 door)', 'Rear-wheel drive (RWD)', 'Manual', 'na', '88,718', 'https://www.carproof.com/order?ref=kijiji&vin=ZAM45KLAXA0053059', '60 Martin Ross Avenue, Toronto, ON, M3J 2L4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-low-kms-pontiac-montana-for-sale/1410151452
# ['Pontiac', 'Montana', '2006', '$1,100.00', 'Silver', 'na', 'Used', 'SUV, Crossover', 'na', 'Automatic', 'Gasoline', '147,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Norman Ross Dr, Markham, ON L3S 3E8, Canada']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2011-chrysler-300-limited-loaded-leather-e-tested/1410151234
# ['Chrysler', '300-Series', '2011', '$3,400.00', 'Black', 'LIMITED', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '176,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9C 1G5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-malibu-ltleather-navi-panoroof/1410151007
# ['Chevrolet', 'Malibu', '2017', '$19,999.00', 'Blue', 'LTLEATHER|NAVI|PANOROOF|', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '41,432', 'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990', '2701 Derry Rd. E, Mississauga, ON, L4T 1A2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-honda-civic-sedan-lx-certified/1410150265
# ['Honda', 'Civic', '2017', '$11,971.00', 'White', 'LX', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '21,196', 'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405', '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-porsche-cayenne/1410150278
# ['Porsche', 'Cayenne', '2013', 'na', 'White', 'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '154,000', 'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831', '46 Milvan Drive, Toronto, ON, M9L 1Z3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-toyota-corolla-ce/1410150845
# ['Toyota', 'Corolla', '2006', '$2,600.00', 'na', 'na', 'Used', 'Sedan', 'na', 'Automatic', 'na', '226', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M4B2E5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-ford-escape-se-62-wk-heated-seat-alloys-backup-camera/1385281347
# ['Ford', 'Escape', '2015', '$15,988.00', 'White', 'SE, $62/wk, heated seat, alloys, backup camera', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'Gasoline', '74,899', 'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026', '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2001-cadillac-dhs/1410150459
# ['Cadillac', 'DeVille', '2001', '$1,000.00', 'Burgundy', 'DHS', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '200,000', 'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388', 'Woodbridge, ON L4L 8L6']
# https://www.kijiji.ca/v-cars-trucks/peterborough/2018-nissan-frontier-pro-4x-navigation-leather-roof/1394329284
# ['Nissan', 'Frontier', '2018', '$31,990.00', 'Black', 'PRO-4X/NAVIGATION/LEATHER/ ROOF', 'Used', 'Pickup Truck', '4 x 4', 'Automatic', 'Gasoline', '15,700', 'https://www.carproof.com/order?ref=kijiji&vin=1N6AD0EV0JN756541', '4 Harvest Street, Lindsay, ON, K9V 4W9']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2016-volkswagen-jetta-1-4tsi-trendline-aut0-sunroof-backup-came/1396470123
# ['Volkswagen', 'Jetta', '2016', '$13,250.00', 'Black', '1.4TSI TRENDLINE+ AUT0 SUNROOF BACKUP CAMERA 107K', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '107,025', 'https://www.carproof.com/order?ref=kijiji&vin=3VW267AJ5GM264505', '1235 Finch Ave. W., Toronto, ON, M3J 2G4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-honda-accord-se/1409875403
# ['Honda', 'Accord', '2017', '$21,588.00', 'White', 'SE', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'na', '24,730', 'https://www.carproof.com/order?ref=kijiji&vin=1HGCR2F75HA803235', '321 Front Street East, Toronto, ON, M5A 1G3']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/mercedes-benz-dodge-sprinter-diesel-vans-for-sale/1235701497
# ['Mercedes-Benz', 'Other', '2008', '$15,999.00', 'White', 'WWW.MOLANDSONS.CA', 'Used', 'Other', 'Other', 'Automatic', 'Diesel', 'N/A', 'https://www.carproof.com/order?ref=kijiji&vin=null', '1897 Wilson Avenue, North York, ON, M9M 1A2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-low-kms-pontiac-montana-for-sale/1410151452
# ['Pontiac', 'Montana', '2006', '$1,100.00', 'Silver', 'na', 'Used', 'SUV, Crossover', 'na', 'Automatic', 'Gasoline', '147,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Norman Ross Dr, Markham, ON L3S 3E8, Canada']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2011-chrysler-300-limited-loaded-leather-e-tested/1410151234
# ['Chrysler', '300-Series', '2011', '$3,400.00', 'Black', 'LIMITED', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '176,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9C 1G5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-malibu-ltleather-navi-panoroof/1410151007
# ['Chevrolet', 'Malibu', '2017', '$19,999.00', 'Blue', 'LTLEATHER|NAVI|PANOROOF|', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '41,432', 'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990', '2701 Derry Rd. E, Mississauga, ON, L4T 1A2']
# ...
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2004-bmw-4-8-is/1410173731
# ['BMW', 'X5', '2004', '$3,900.00', 'Red', 'na', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'na', '277,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', '3891 Keele St, Unit B, North York, ON, M3J 1N6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2014-mercedes-benz-slk-class-slk55-amg-v8-navi/1407540332
# ['Mercedes-Benz', 'SLK-Class', '2014', '$45,800.00', 'White', 'SLK55 AMG V8, NAVI,', 'Used', 'Convertible', 'Rear-wheel drive (RWD)', 'Automatic', 'na', '65,273', 'https://www.carproof.com/order?ref=kijiji&vin=WDDPK7FA5EF090595', '60 Martin Ross Avenue, Toronto, ON, M3J 2L4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2014-fiat-500-abarth-5-speed-sun/1406811854
# ['Fiat', '500', '2014', '$12,800.00', 'Other', 'ABARTH, 5 SPEED, SUN', 'Used', 'Hatchback', 'Front-wheel drive (FWD)', 'Manual', 'na', '76,906', 'https://www.carproof.com/order?ref=kijiji&vin=3C3CFFFH7ET293230', '60 Martin Ross Avenue, Toronto, ON, M3J 2L4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-audi-rs5-4-2-quattro-450hp/1406859522
# ['Audi', 'S5', '2013', '$35,800.00', 'Black', '4.2 QUATTRO, 450HP,', 'Used', 'Coupe (2 door)', 'All-wheel drive (AWD)', 'Automatic', 'na', '136,200', 'https://www.carproof.com/order?ref=kijiji&vin=WUAC6BFR0DA901708', '60 Martin Ross Avenue, Toronto, ON, M3J 2L4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-mazda-mazda3-special-price-offer-for-gx-model-skyactive/1374011462
# ['Mazda', 'Mazda3', '2015', '$9,999.00', 'Grey', 'Special Price Offer For GX MODEL, SKYACTIVE', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Manual', 'Gasoline', '71,918', 'https://www.carproof.com/order?ref=kijiji&vin=JM1BM1U79F1275217', '3675 Keele Street, Toronto, ON, M3J 1M6']
# https://www.kijiji.ca/v-cars-trucks/markham-york-region/2017-jaguar-f-type-coupe-r-550hp-active-exhaust/1380507225
# ['Jaguar', 'Other', '2017', '$87,990.00', 'White', 'Coupe R 550HP!! Active Exhaust!', 'Used', 'Sedan', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', '48,784', 'https://www.carproof.com/order?ref=kijiji&vin=SAJXJ6DL8HMK41412', '123 Auto Park Circle, Woodbridge, ON, L4L 8R1']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-nissan-sentra-sl-model-leather-seats-sunroof-navigation/1398366394
# ['Nissan', 'Sentra', '2015', '$13,999.00', 'White', 'SL MODEL, LEATHER SEATS, SUNROOF, NAVIGATION', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Other', 'Gasoline', '75,203', 'https://www.carproof.com/order?ref=kijiji&vin=3N1AB7AP7FL649442', '3675 Keele Street, Toronto, ON, M3J 1M6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-volkswagen-jetta-2-0l-trendline-5-speed-a-c-h-seats-rear-ca/1405388778
# ['Volkswagen', 'Jetta', '2015', '$9,500.00', 'White', '2.0L TRENDLINE 5 SPEED A/C H/SEATS REAR CAMERA 67K', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Manual', 'na', '67,069', 'https://reports.carproof.com/en/main?id=IwjEf/IknJjv3y6vUsaQogmqQHyEVIGQ&utm_ref=kijiji', '1235 Finch Ave. W., Toronto, ON, M3J 2G4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-mercedes-benz-m-class-ml-350-bluetec-4matic-navigation/1400162468
# ['Mercedes-Benz', 'M-Class', '2015', '$35,999.00', 'Grey', 'ML 350 BlueTEC 4MATIC NAVIGATION,', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'Gasoline', '62,000', 'https://www.carproof.com/order?ref=kijiji&vin=4JGDA2EB0FA579512', '1100 Finch Avenue West, Unit 11D, North York, ON, M3J 2E2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2008-chevy-uplander-ext-150000-km/1399416719
# ['Chevrolet', 'Uplander', '2008', '$3,899.00', 'Blue', 'EXT', 'Used', 'Minivan, Van', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '150,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9W 7J4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/more-cash-for-scrap-cars-used-cars-4165406783/1372152494
# ['Pontiac', 'Grand Am', '2000', 'na', 'Gold', 'na', 'Used', 'Sedan', 'na', 'na', 'na', '350,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M9L1R2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/top-cash-for-your-scrap-cars-and-used-cars-416-540-6783/1397362061
# ['Toyota', 'Corolla', '2004', 'na', 'Grey', 'na', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '505,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Vaughan, ON L4L']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2016-acura-mdx-navi-7yrs-130-000k-certified-warranty-inlcuded/1406371812
# ['Acura', 'MDX', '2016', '$33,182.00', 'Silver', 'Navi 7yrs/130,000K Certified Warranty Inlcuded', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'na', '44,660', 'https://www.carproof.com/order?ref=kijiji&vin=5FRYD4H45GB505404', '7064 Yonge Street, Thornhill, ON, L4J 1V7']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-sonic-lt-with-incentive/1410176604
# ['Chevrolet', 'Sonic', '2020', '$298.00', 'White', 'LT', 'Lease Takeover', 'Hatchback', 'Front-wheel drive (FWD)', 'Automatic', 'na', '20,800', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M1P5E4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2009-kia-rio-rio5-ex-sport-safety-etest-included-price/1410175958
# ['Kia', 'Rio', '2009', '$3,999.00', 'White', 'Rio5 EX Sport/Safety/ETest included Price', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '115,000', 'https://www.carproof.com/order?ref=kijiji&vin=KNADE243396560749', '3406 Kingston Road, Toronto, ON, M1M 1R2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2019-chevrolet-equinox-lt/1410176457
# ['Chevrolet', 'Equinox', '2019', '$39,160.00', 'Black', 'LT', 'New', 'Wagon', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', 'na', 'na', '3180 Dufferin Street, Toronto, ON, M6A 2T1']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2019-chevrolet-traverse-lt-cloth/1410176459
# ['Chevrolet', 'Traverse', '2019', '$43,050.00', 'White', 'LT Cloth', 'New', 'Wagon', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', 'na', 'na', '3180 Dufferin Street, Toronto, ON, M6A 2T1']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2010-gmc-sierra-1500-4x4-4-8l-regular-cab-8-box-as-is-special/1410176017
# ['GMC', 'Sierra 1500', '2010', '$3,700.00', 'Black', '4X4 4.8L V8 Regular Cab 8Ft Box "AS IS" Special', 'Used', 'Pickup Truck', '4 x 4', 'Automatic', 'Gasoline', '314,000', 'https://www.carproof.com/order?ref=kijiji&vin=1GTPKTEA3AZ127222', '1065 Martin Grove Road, Toronto, ON, M9W 4W6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2019-chevrolet-traverse-ls/1410176458
# ['Chevrolet', 'Traverse', '2019', '$38,645.00', 'Black', 'LS', 'New', 'Wagon', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', 'na', 'na', '3180 Dufferin Street, Toronto, ON, M6A 2T1']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2019-jeep-wrangler-unlimited-rubicon-373-53-b-w/1410176436
# ['Jeep', 'Wrangler', '2019', '$64,010.00', 'Red', 'Rubicon', 'New', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Manual', 'na', 'na', 'na', '17615 Yonge Street, Newmarket, ON, L3Y 5H6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2006-nissan-altima-2-5-s-p-group-certified/1410176433
# ['Nissan', 'Altima', '2006', '$3,475.00', 'Blue', '2.5 S P.group, Certified', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '172,485', 'https://www.carproof.com/order?ref=kijiji&vin=1N4AL11D56C135054', '6470 Kingston Road, Scarborough, ON, M1C 1L4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2004-honda-pilot/1410176340
# ['Honda', 'Pilot', '2004', '$2,999.00', 'Silver', 'na', 'Used', 'SUV, Crossover', 'All-wheel drive (AWD)', 'Automatic', 'na', '161,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', '3891 Keele St, Unit B, North York, ON, M3J 1N6']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-volkswagen-golf-tdi-wagon-sunroof-diesel/1402320977
# ['Volkswagen', 'Golf', '2013', '$8,888.00', 'Gold', 'TDI | WAGON | PANOROOF | DIESEL', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Diesel', '149,683', 'https://www.carproof.com/order?ref=kijiji&vin=null', '1882 Lawrence Avenue East, Scarborough, ON, M1R 2Y5']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2015-volkswagen-jetta-2-0l-trendline-aut0-a-c-h-seats-rear-camer/1402230761
# ['Volkswagen', 'Jetta', '2015', '$13,990.00', 'Black', '2.0L TRENDLINE AUT0 A/C H/SEATS REAR CAMERA 49K', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '49,353', 'https://www.carproof.com/order?ref=kijiji&vin=3VW2K7AJ9FM287652', '1235 Finch Ave. W., Toronto, ON, M3J 2G4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2013-honda-civic-touring-pkg-navigation-leather-sunroof-back-up/1407245392
# ['Honda', 'Civic', '2013', '$14,450.00', 'Black', 'TOURING PKG NAVIGATION LEATHER SUNROOF BACK UP CAM', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'na', '85,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', '1205 Finch Avenue West, Toronto, ON, M3J 2E8']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2008-chevy-uplander-ext-150000-km/1399416719
# ['Chevrolet', 'Uplander', '2008', '$3,899.00', 'Blue', 'EXT', 'Used', 'Minivan, Van', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '150,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Etobicoke, ON M9W 7J4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/more-cash-for-scrap-cars-used-cars-4165406783/1372152494
# ['Pontiac', 'Grand Am', '2000', 'na', 'Gold', 'na', 'Used', 'Sedan', 'na', 'na', 'na', '350,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M9L1R2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/top-cash-for-your-scrap-cars-and-used-cars-416-540-6783/1397362061
# ['Toyota', 'Corolla', '2004', 'na', 'Grey', 'na', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '505,000', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Vaughan, ON L4L']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2016-acura-mdx-navi-7yrs-130-000k-certified-warranty-inlcuded/1406371812
# ['Acura', 'MDX', '2016', '$33,182.00', 'Silver', 'Navi 7yrs/130,000K Certified Warranty Inlcuded', 'Used', 'SUV, Crossover', 'Other', 'Automatic', 'na', '44,660', 'https://www.carproof.com/order?ref=kijiji&vin=5FRYD4H45GB505404', '7064 Yonge Street, Thornhill, ON, L4J 1V7']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2017-chevrolet-sonic-lt-with-incentive/1410176604
# ['Chevrolet', 'Sonic', '2020', '$298.00', 'White', 'LT', 'Lease Takeover', 'Hatchback', 'Front-wheel drive (FWD)', 'Automatic', 'na', '20,800', 'https://www.carproof.com/order?ref=kijiji&vin=null', 'Toronto, ON M1P5E4']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2009-kia-rio-rio5-ex-sport-safety-etest-included-price/1410175958
# ['Kia', 'Rio', '2009', '$3,999.00', 'White', 'Rio5 EX Sport/Safety/ETest included Price', 'Used', 'Sedan', 'Front-wheel drive (FWD)', 'Automatic', 'Gasoline', '115,000', 'https://www.carproof.com/order?ref=kijiji&vin=KNADE243396560749', '3406 Kingston Road, Toronto, ON, M1M 1R2']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2019-chevrolet-equinox-lt/1410176457
# ['Chevrolet', 'Equinox', '2019', '$39,160.00', 'Black', 'LT', 'New', 'Wagon', 'All-wheel drive (AWD)', 'Automatic', 'Gasoline', 'na', 'na', '3180 Dufferin Street, Toronto, ON, M6A 2T1']
# https://www.kijiji.ca/v-cars-trucks/city-of-toronto/2019-chevrolet-traverse-lt-cloth/1410176459
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-75-8dccd0d37428> in <module>()
#      10             if '?' not in item_url:
#      11                 print(item_url)
# ---> 12                 itemlist = get_item_info(item_url)
#      13                 print(itemlist)
#      14                 all_info_list.append(itemlist)
#
# <ipython-input-60-b79d644035b1> in get_item_info(url)
#       3
#       4
# ----> 5     html = urlopen(url)
#       6     bs_item = BeautifulSoup(html, 'html.parser')
#       7
#
# ~/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# ~/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# ~/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# ConnectionResetError: [Errno 54] Connection reset by peer

# %%
all_info_list
# Out:
# [['Chevrolet',
#   'Silverado 1500',
#   '2017',
#   '$30,999.99',
#   'Black',
#   'LT',
#   'Used',
#   'Pickup Truck',
#   '4 x 4',
#   'Automatic',
#   'Gasoline',
#   '115,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=3GCUKRECXHG233474',
#   'Brydon Drive, Etobicoke, ON'],
#  ['Volkswagen',
#   'Tiguan',
#   '2013',
#   '$11,450.00',
#   'Grey',
#   'COMFORTLINE  4WD',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '129,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '1205 Finch Avenue West, Toronto, ON, M3J 2E8'],
#  ['GMC',
#   'Acadia',
#   '2017',
#   '$33,988.00',
#   'Other',
#   'SLT-2',
#   'Used',
#   'Other',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '73,893',
#   'https://reports.carproof.com/en/main?id=ioaVnMDRqWSUYvSqQx36orRln0cVjAqC&utm_ref=kijiji',
#   '1900 Victoria Park Avenue, Toronto, ON, M1R 1T6'],
#  ['Acura',
#   'TL',
#   '2002',
#   '$500.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'na',
#   'na',
#   '200,500',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M5N1A1'],
#  ['Honda',
#   'Accord',
#   '2015',
#   '$15,499.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '93,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=1HGCR2F36FA803335',
#   '1726 Kingston Road, Scarborough, ON, M1N 1S8'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Ford',
#   'Escape',
#   '2015',
#   '$15,988.00',
#   'White',
#   'SE, $62/wk, heated seat, alloys, backup camera',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '74,899',
#   'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026',
#   '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6'],
#  ['Cadillac',
#   'DeVille',
#   '2001',
#   '$1,000.00',
#   'Burgundy',
#   'DHS',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '200,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388',
#   'Woodbridge, ON L4L 8L6'],
#  ['Ford',
#   'Edge',
#   '2018',
#   '$43,578.00',
#   'Silver',
#   '1 OWNER, Accident Free, Navi, Heated Seats, AWD',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '11,618',
#   'https://www.carproof.com/order?ref=kijiji&vin=2FMPK4AP1JBB18212',
#   '2595 Saint Clair Avenue West, Toronto, ON, M6N 4Z5'],
#  ['Toyota',
#   'Other',
#   '2012',
#   '$11,500.00',
#   'na',
#   'LE',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Hybrid-Electric',
#   '156,988',
#   'https://www.carproof.com/order?ref=kijiji&vin=4T1BD1FK6CU022427',
#   'Toronto, ON M1X0B1'],
#  ['BMW',
#   '3-Series',
#   '2014',
#   '$21,500.00',
#   'Red',
#   '320I X DRIVE SPORT+ NAVI PKG AUT0 SUNROOF 103K',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '103,558',
#   'https://www.carproof.com/order?ref=kijiji&vin=WBA3C3C57EP661923',
#   '1235 Finch Ave. W., Toronto, ON, M3J 2G4'],
#  ['Tesla',
#   'na',
#   '2015',
#   '$93,995.00',
#   'Blue',
#   'Autopilot, 21Whls, Sunroof, INSANE Mode, EV',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Hybrid-Electric',
#   '27,981',
#   'https://reports.carproof.com/en/main?id=ig5IdGR Tn7AKuTK3l D0/dbTFYkLIFw&utm_ref=kijiji',
#   '212 Lakeshore Road West, Mississauga, ON, L5H 1G6'],
#  ['Toyota',
#   'RAV4',
#   '2014',
#   '$15,950.00',
#   'Grey',
#   'LE AWD',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '131,000',
#   'https://reports.carproof.com/en/main?id=DCWc4i5kYytt1E0PJOoumZeukle/VlgJ&utm_ref=kijiji',
#   '1205 Finch Avenue West, Toronto, ON, M3J 2E8'],
#  ['Honda',
#   'Civic',
#   '2016',
#   '$21,877.00',
#   'White',
#   'EX-T w/Honda Sensing/SUNROOF/REAR CAMERA !!!',
#   'Used',
#   'Coupe (2 door)',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '30,345',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC3B42GH425293',
#   '2685 Highway 7 West, Concord, ON, L4K 1V8'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Ford',
#   'Escape',
#   '2015',
#   '$15,988.00',
#   'White',
#   'SE, $62/wk, heated seat, alloys, backup camera',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '74,899',
#   'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026',
#   '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6'],
#  ['Cadillac',
#   'DeVille',
#   '2001',
#   '$1,000.00',
#   'Burgundy',
#   'DHS',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '200,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388',
#   'Woodbridge, ON L4L 8L6'],
#  ['Honda',
#   'Accord',
#   '2014',
#   '$16,950.00',
#   'Grey',
#   'TOURING NAVIGATION LEATHER SUNROOF BACK UP CAMERA',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '123,000',
#   'https://reports.carproof.com/en/main?id=34OnNI4CMaISU IE/u9OXBCX6HCa7d1T&utm_ref=kijiji',
#   '1205 Finch Avenue West, Toronto, ON, M3J 2E8'],
#  ['Honda',
#   'Other',
#   '2006',
#   '$1,190.00',
#   'Red',
#   'LIKE NEW!!/CHRISTMAS SPECIAL!!',
#   'Used',
#   'Sedan',
#   'Other',
#   'Other',
#   'Gasoline',
#   '513',
#   'https://www.carproof.com/order?ref=kijiji&vin=JH2AF60296K400313',
#   '4 Harvest Street, Lindsay, ON, K9V 4W9'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   '$53,988.00',
#   'White',
#   'GTS/NAV/PORSCHE ENTRY&DRIVE/LANE CHANGE ASSIST',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '69,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Audi',
#   'S4',
#   '2012',
#   '$21,800.00',
#   'Black',
#   '3.0T QUATTRO PREM, N',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '114,208',
#   'https://www.carproof.com/order?ref=kijiji&vin=WAUBGCFL5CA111274',
#   '60 Martin Ross Avenue, Toronto, ON, M3J 2L4'],
#  ['BMW',
#   'X5',
#   '2012',
#   '$20,500.00',
#   'White',
#   'X DRIVE 35i M SPORT + ACTIVITY + PREMIUM PKG',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '147,168',
#   'https://www.carproof.com/order?ref=kijiji&vin=5UXZV4C50CL746845',
#   '1235 Finch Ave. W., Toronto, ON, M3J 2G4'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Ford',
#   'Escape',
#   '2015',
#   '$15,988.00',
#   'White',
#   'SE, $62/wk, heated seat, alloys, backup camera',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '74,899',
#   'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026',
#   '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6'],
#  ['Cadillac',
#   'DeVille',
#   '2001',
#   '$1,000.00',
#   'Burgundy',
#   'DHS',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '200,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388',
#   'Woodbridge, ON L4L 8L6'],
#  ['Toyota',
#   'Yaris',
#   '2008',
#   '$4,995.00',
#   'Blue',
#   'sedan',
#   'Used',
#   'Sedan',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '140,373',
#   'https://www.carproof.com/order?ref=kijiji&vin=JTDBT923X81226449',
#   '1037 Belfast Road, Ottawa, ON, K1B 3S2'],
#  ['Volkswagen',
#   'Jetta',
#   '2015',
#   '$9,500.00',
#   'White',
#   '2.0L TRENDLINE 5 SPEED A/C H/SEATS REAR CAMERA 67K',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Manual',
#   'na',
#   '67,069',
#   'https://reports.carproof.com/en/main?id=IwjEf/IknJjv3y6vUsaQogmqQHyEVIGQ&utm_ref=kijiji',
#   '1235 Finch Ave. W., Toronto, ON, M3J 2G4'],
#  ['BMW',
#   '5-Series',
#   '2014',
#   '$32,800.00',
#   'Black',
#   '535d xDrive, NAVI, M',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '78,690',
#   'https://www.carproof.com/order?ref=kijiji&vin=WBAFV3C57ED684353',
#   '60 Martin Ross Avenue, Toronto, ON, M3J 2L4'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Ford',
#   'Escape',
#   '2015',
#   '$15,988.00',
#   'White',
#   'SE, $62/wk, heated seat, alloys, backup camera',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '74,899',
#   'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026',
#   '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6'],
#  ['Cadillac',
#   'DeVille',
#   '2001',
#   '$1,000.00',
#   'Burgundy',
#   'DHS',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '200,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388',
#   'Woodbridge, ON L4L 8L6'],
#  ['Hyundai',
#   'Elantra',
#   '2017',
#   '$14,850.00',
#   'Red',
#   'GLS SUNROOF ALLOYS BACK UP CAMERA',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '103,000',
#   'https://reports.carproof.com/en/main?id=VRTtr/bu8HcxWy1UVsqM08CgyGVqEC21&utm_ref=kijiji',
#   '1205 Finch Avenue West, Toronto, ON, M3J 2E8'],
#  ['Hyundai',
#   'Santa Fe',
#   '2019',
#   'na',
#   'Silver',
#   'Ultimate',
#   'New',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   'na',
#   'na',
#   '1962 Eagle Street North, Cambridge, ON, N3H 0A1'],
#  ['Mercedes-Benz',
#   'S-Class',
#   '2008',
#   '$19,000.00',
#   'Black',
#   'S550',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '150,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Scarborough, ON M1L 4S2'],
#  ['Volkswagen',
#   'Passat',
#   '2015',
#   '$15,950.00',
#   'White',
#   '1.8 TSI HIGHLINE NAVIGATION LEATHER SUNROOF',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '126,000',
#   'https://reports.carproof.com/en/main?id=7jXAgPYG7tt7JYcucHoV2fzGgWauR3H9&utm_ref=kijiji',
#   '1205 Finch Avenue West, Toronto, ON, M3J 2E8'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Ford',
#   'Escape',
#   '2015',
#   '$15,988.00',
#   'White',
#   'SE, $62/wk, heated seat, alloys, backup camera',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '74,899',
#   'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026',
#   '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6'],
#  ['Cadillac',
#   'DeVille',
#   '2001',
#   '$1,000.00',
#   'Burgundy',
#   'DHS',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '200,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388',
#   'Woodbridge, ON L4L 8L6'],
#  ['Honda',
#   'Accord',
#   '2015',
#   '$17,500.00',
#   'Black',
#   'Sport  | Sunroof | Rear Camera | Heated Seats',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '106,501',
#   'https://reports.carproof.com/en/main?id=QYMD5ev6wfpAtxy1p1VdZFI56G3AUtQ0&utm_ref=kijiji',
#   '430 Hensall Cir, Mississauga, ON, L5A 1X7'],
#  ['Honda',
#   'Civic',
#   '2015',
#   '$13,980.00',
#   'White',
#   'EX-AUTO-SUNROOF-CAMERA-ONLY 85KM',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '85,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFB2F5XFH013248',
#   '301 Weston Road, Toronto, ON, M6N3P1'],
#  ['Infiniti',
#   'FX',
#   '2012',
#   '$20,950.00',
#   'Black',
#   'Limited Edition',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '140,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=JN8AS1MW3CM153511',
#   '11 Saint Regis Crescent North, North York, ON, M3J 1Y9'],
#  ['Mazda',
#   'Mazda3',
#   '2014',
#   '$10,400.00',
#   'Black',
#   'GX MODEL, SKYACTIV',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Manual',
#   'Gasoline',
#   '67,800',
#   'https://www.carproof.com/order?ref=kijiji&vin=3MZBM1U7XEM122618',
#   '3675 Keele Street, Toronto, ON, M3J 1M6'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Ford',
#   'Escape',
#   '2015',
#   '$15,988.00',
#   'White',
#   'SE, $62/wk, heated seat, alloys, backup camera',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '74,899',
#   'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026',
#   '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6'],
#  ['Cadillac',
#   'DeVille',
#   '2001',
#   '$1,000.00',
#   'Burgundy',
#   'DHS',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '200,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388',
#   'Woodbridge, ON L4L 8L6'],
#  ['BMW',
#   'Other',
#   '2015',
#   '$23,799.00',
#   'Grey',
#   'LUXURY|NAVI|REAR CAM|X-DRIVE',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '74,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WBA3B3G52FNR87199',
#   '150 Deerhide Crescent, North York, ON, M9M 2Y6'],
#  ['Ford',
#   'Edge',
#   '2015',
#   '$23,495.00',
#   'Black',
#   'SEL | AWD | TRADE-IN |',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '74,496',
#   'https://reports.carproof.com/en/main?id=CAqdOt0UM3B9lVuJfZJeoaSefEQ3JZ Y&utm_ref=kijiji',
#   '190 Canam Crescent, Brampton, ON, L7A 1A9'],
#  ['Mercedes-Benz',
#   'Other',
#   '2014',
#   '$23,800.00',
#   'White',
#   'CLA250, AMG SPORT, N',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '57,080',
#   'https://www.carproof.com/order?ref=kijiji&vin=WDDSJ4EB0EN134899',
#   '60 Martin Ross Avenue, Toronto, ON, M3J 2L4'],
#  ['Audi',
#   'A6',
#   '2016',
#   '$36,388.00',
#   'White',
#   '2.0T Progressiv | AWD | BROWN LEATHER | S-LINE PKG',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '26,188',
#   'https://www.carproof.com/order?ref=kijiji&vin=WAUJFAFC4GN053725',
#   '354 Richmond St E, Toronto, ON, M5A 1P7'],
#  ['BMW',
#   '3-Series',
#   '2014',
#   '$24,950.00',
#   'Black',
#   '328i xDrive',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '66,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WBA3X5C5XED559212',
#   '11 Saint Regis Crescent North, North York, ON, M3J 1Y9'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Ford',
#   'Escape',
#   '2015',
#   '$15,988.00',
#   'White',
#   'SE, $62/wk, heated seat, alloys, backup camera',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '74,899',
#   'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026',
#   '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6'],
#  ['Cadillac',
#   'DeVille',
#   '2001',
#   '$1,000.00',
#   'Burgundy',
#   'DHS',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '200,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388',
#   'Woodbridge, ON L4L 8L6'],
#  ['Acura',
#   'ILX',
#   '2015',
#   '$16,450.00',
#   'Black',
#   'PREMIUM PKG LEATHER SUNROOF BACK UP CAMERA',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '96,000',
#   'https://reports.carproof.com/en/main?id=QCZbdKW6IA0xcRZV2AVtrZxI8hjcSESc&utm_ref=kijiji',
#   '1205 Finch Avenue West, Toronto, ON, M3J 2E8'],
#  ['Volkswagen',
#   'Golf',
#   '2017',
#   '$34,950.00',
#   'White',
#   '2.0 TSI LEATHER NAV 19ALLOYS WOW!!',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '40,250',
#   'https://www.carproof.com/order?ref=kijiji&vin=WVWVF7AUXHW013913',
#   '880 Merivale Road, Ottawa, ON, K1Z 5Z6'],
#  ['Chrysler',
#   '300-Series',
#   '2017',
#   '$24,677.00',
#   'Black',
#   'S LEATHER/ALL WHEEL DRIVE/8.4 INCH TOUCH SCREEN',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '52,745',
#   'https://www.carproof.com/order?ref=kijiji&vin=2C3CCAGG8HH631541',
#   '2685 Highway 7 West, Concord, ON, L4K 1V8'],
#  ['Acura',
#   'MDX',
#   '2017',
#   '$46,995.00',
#   'Blue',
#   'ELITE|NAVI|DVD|360CAM|LDWS|LKA|1 OWNER',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '37,245',
#   'https://www.carproof.com/order?ref=kijiji&vin=5FRYD4H89HB504458',
#   '2730 Markham Road, Scarborough, ON, M1X 1E6'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Ford',
#   'Escape',
#   '2015',
#   '$15,988.00',
#   'White',
#   'SE, $62/wk, heated seat, alloys, backup camera',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '74,899',
#   'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026',
#   '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6'],
#  ['Cadillac',
#   'DeVille',
#   '2001',
#   '$1,000.00',
#   'Burgundy',
#   'DHS',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '200,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388',
#   'Woodbridge, ON L4L 8L6'],
#  ['Toyota',
#   'Corolla',
#   '2017',
#   '$14,999.00',
#   'Grey',
#   'LE-AUTO-CAMERA-HEATED SEATS-ONLY 58KM',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '58,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=2T1BURHE5HC921407',
#   '301 Weston Road, Toronto, ON, M6N3P1'],
#  ['Chevrolet',
#   'Equinox',
#   '2013',
#   '$13,495.00',
#   'White',
#   'LT *Nav. Back up Cam. Heated Seats*',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '124,506',
#   'https://www.carproof.com/order?ref=kijiji&vin=2GNFLEEK5D6395306',
#   '20600 County Rd 42 West, Tilbury, ON, N0P 2L0'],
#  ['Volkswagen',
#   'Tiguan',
#   '2015',
#   '$14,990.00',
#   'Blue',
#   '2.0TSI TRENDLINE AUT0 A/C H/SEATS REAR CAMERA 51K',
#   'Used',
#   'SUV, Crossover',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '51,628',
#   'https://reports.carproof.com/en/main?id=Vjk2rHVWZyluK7Bsin1enVoimD1kqUwI&utm_ref=kijiji',
#   '1235 Finch Ave. W., Toronto, ON, M3J 2G4'],
#  ['Mercedes-Benz',
#   'M-Class',
#   '2011',
#   '$17,988.00',
#   'Grey',
#   'DIESEL/NAV/KEYLESSGO/BACK-UP CAM/LOADED',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '129,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=4JGBB2FB2BA671961',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['BMW',
#   '4-Series',
#   '2014',
#   '$22,999.00',
#   'Red',
#   '428i|NAVI|ROOF|XEONLIGHTS|',
#   'Used',
#   'Coupe (2 door)',
#   'Rear-wheel drive (RWD)',
#   'Automatic',
#   'Gasoline',
#   '86,758',
#   'https://www.carproof.com/order?ref=kijiji&vin=WBA3N3C50EF710878',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Ford',
#   'Escape',
#   '2015',
#   '$15,988.00',
#   'White',
#   'SE, $62/wk, heated seat, alloys, backup camera',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '74,899',
#   'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026',
#   '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6'],
#  ['Cadillac',
#   'DeVille',
#   '2001',
#   '$1,000.00',
#   'Burgundy',
#   'DHS',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '200,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388',
#   'Woodbridge, ON L4L 8L6'],
#  ['Jeep',
#   'Cherokee',
#   '2014',
#   '$17,950.00',
#   'Grey',
#   'LIMITED NAVIGATION LEATHER AWD',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '116,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '1205 Finch Avenue West, Toronto, ON, M3J 2E8'],
#  ['BMW',
#   '3-Series',
#   '2013',
#   '$19,285.00',
#   'Brown',
#   '328i xDrive',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '30,623',
#   'https://www.carproof.com/order?ref=kijiji&vin=WBA3B3C59DF539815',
#   '55 Benson Court, Port Hope, ON, L1A 2M6'],
#  ['Audi',
#   'Q5',
#   '2014',
#   '$29,800.00',
#   'Black',
#   '3.0T QUATTRO TECHNIK',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '144,411',
#   'https://www.carproof.com/order?ref=kijiji&vin=WA1LGCFP7EA088393',
#   '60 Martin Ross Avenue, Toronto, ON, M3J 2L4'],
#  ['BMW',
#   '3-Series',
#   '2007',
#   '$9,995.00',
#   'Grey',
#   '328i',
#   'Used',
#   'Convertible',
#   'Rear-wheel drive (RWD)',
#   'Automatic',
#   'Gasoline',
#   '121,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WBAWL13507PX16944',
#   '4490 Chesswood Drive Unit 2, Toronto, ON, M3J 2B9'],
#  ['Maserati',
#   'Gran Turismo',
#   '2010',
#   '$46,800.00',
#   'Black',
#   'S 4.7, NAVI, PARK SE',
#   'Used',
#   'Coupe (2 door)',
#   'Rear-wheel drive (RWD)',
#   'Manual',
#   'na',
#   '88,718',
#   'https://www.carproof.com/order?ref=kijiji&vin=ZAM45KLAXA0053059',
#   '60 Martin Ross Avenue, Toronto, ON, M3J 2L4'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Ford',
#   'Escape',
#   '2015',
#   '$15,988.00',
#   'White',
#   'SE, $62/wk, heated seat, alloys, backup camera',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '74,899',
#   'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026',
#   '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6'],
#  ['Cadillac',
#   'DeVille',
#   '2001',
#   '$1,000.00',
#   'Burgundy',
#   'DHS',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '200,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G6KE54Y01U191388',
#   'Woodbridge, ON L4L 8L6'],
#  ['Nissan',
#   'Frontier',
#   '2018',
#   '$31,990.00',
#   'Black',
#   'PRO-4X/NAVIGATION/LEATHER/ ROOF',
#   'Used',
#   'Pickup Truck',
#   '4 x 4',
#   'Automatic',
#   'Gasoline',
#   '15,700',
#   'https://www.carproof.com/order?ref=kijiji&vin=1N6AD0EV0JN756541',
#   '4 Harvest Street, Lindsay, ON, K9V 4W9'],
#  ['Volkswagen',
#   'Jetta',
#   '2016',
#   '$13,250.00',
#   'Black',
#   '1.4TSI TRENDLINE+ AUT0 SUNROOF BACKUP CAMERA 107K',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '107,025',
#   'https://www.carproof.com/order?ref=kijiji&vin=3VW267AJ5GM264505',
#   '1235 Finch Ave. W., Toronto, ON, M3J 2G4'],
#  ['Honda',
#   'Accord',
#   '2017',
#   '$21,588.00',
#   'White',
#   'SE',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'na',
#   '24,730',
#   'https://www.carproof.com/order?ref=kijiji&vin=1HGCR2F75HA803235',
#   '321 Front Street East, Toronto, ON, M5A 1G3'],
#  ['Mercedes-Benz',
#   'Other',
#   '2008',
#   '$15,999.00',
#   'White',
#   'WWW.MOLANDSONS.CA',
#   'Used',
#   'Other',
#   'Other',
#   'Automatic',
#   'Diesel',
#   'N/A',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '1897 Wilson Avenue, North York, ON, M9M 1A2'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Ford',
#   'Escape',
#   '2015',
#   '$15,988.00',
#   'White',
#   'SE, $62/wk, heated seat, alloys, backup camera',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '74,899',
#   'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026',
#   '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6'],
#  ['Volkswagen',
#   'Jetta',
#   '2015',
#   '$12,500.00',
#   'White',
#   '2.0L TRENDLINE+ 5 SPEED SUNROOF BACKUP CAMERA 59K',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Manual',
#   'na',
#   '59,996',
#   'https://reports.carproof.com/en/main?id=sd7Jv4GP0KFjA7GnyXG9HBixE7/0LaCO&utm_ref=kijiji',
#   '1235 Finch Ave. W., Toronto, ON, M3J 2G4'],
#  ['Jeep',
#   'Grand Cherokee',
#   '2018',
#   '$50,907.00',
#   'Black',
#   'Summit',
#   'Used',
#   'SUV, Crossover',
#   '4 x 4',
#   'Automatic',
#   'na',
#   '12,861',
#   'https://www.carproof.com/order?ref=kijiji&vin=1C4RJFJG7JC145328',
#   '321 Front Street East, Toronto, ON, M5A 1G3'],
#  ['Hyundai',
#   'Accent',
#   '2011',
#   '$3,250.00',
#   'Blue',
#   'L',
#   'Used',
#   'Coupe (2 door)',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '197,700',
#   'https://www.carproof.com/order?ref=kijiji&vin=KMHCN3BC9BU196213',
#   '1614 Military Trail, Scarborough, ON, M1C 1B2'],
#  ['Dodge',
#   'Sprinter',
#   '2007',
#   'na',
#   'na',
#   'na',
#   'Used',
#   'Other',
#   'na',
#   'na',
#   'na',
#   '200,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'York, ON M9N 1H7, Canada'],
#  ['Mazda',
#   'CX-5',
#   '2013',
#   '$12,850.00',
#   'Black',
#   'GX SPORT | CAR-FAX CLEAN | ONE OWNER | NAVI',
#   'Used',
#   'SUV, Crossover',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '157,365',
#   'https://www.carproof.com/order?ref=kijiji&vin=JM3KE2BE8D0155147',
#   '12030 Yonge Street, Richmond Hill, ON, L4E 3M2'],
#  ['Ford',
#   'F-150',
#   '2018',
#   '$1,000.00',
#   'na',
#   'na',
#   'Used',
#   'Pickup Truck',
#   'na',
#   'na',
#   'na',
#   '88',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '549 King Street East, Toronto, ON'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Ford',
#   'Escape',
#   '2015',
#   '$15,988.00',
#   'White',
#   'SE, $62/wk, heated seat, alloys, backup camera',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'Gasoline',
#   '74,899',
#   'https://www.carproof.com/order?ref=kijiji&vin=1FMCU0GX3FUC83026',
#   '4700 Sheppard Avenue East, Toronto, ON, M1S 3V6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   '$39,800.00',
#   'White',
#   'S | Navigation | Sunroof | One Owner',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '75,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AB2A26DLA80434',
#   '4801 Keele st 18-19, Toronto, ON, M3J 3A4'],
#  ['Hyundai',
#   'Santa Fe',
#   '2019',
#   '$36,535.00',
#   'Black',
#   'Preferred',
#   'New',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   'na',
#   'na',
#   '5515 Ambler Drive, Mississauga, ON, L4W 4N3'],
#  ['Mercedes-Benz',
#   'GL-Class',
#   '2009',
#   '$11,995.00',
#   'Black',
#   '3.0L BlueTEC',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '199,461',
#   'https://www.carproof.com/order?ref=kijiji&vin=4JGBF25E19A529712',
#   '2020 Wilson Avenue, Toronto, ON, M9M 1B3'],
#  ['Pontiac',
#   'G5',
#   '2008',
#   '$2,699.95',
#   'Blue',
#   'CPE SE 1SB',
#   'Used',
#   'Coupe (2 door)',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '204,710',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G2AL15F087300093',
#   '230 Pellatt Avenue, North York, ON'],
#  ['Chevrolet',
#   'Express',
#   '2009',
#   '$18,995.00',
#   'Silver',
#   'Extended Cargo Duramax Diesel Loaded ONLY 168,000K',
#   'Used',
#   'Minivan, Van',
#   'Rear-wheel drive (RWD)',
#   'Automatic',
#   'Diesel',
#   '168,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=1GCHG396791108484',
#   '1065 Martin Grove Road, Toronto, ON, M9W 4W6'],
#  ['Kia',
#   'Rondo',
#   '2010',
#   'na',
#   'Silver',
#   'na',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   'N/A',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '4249 Kingston Road, Scarborough, ON, M1E 2M5'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$18,999.00',
#   'White',
#   'LX|REARVIEW|CLEANCARPROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'na',
#   '42,276',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F52HH005788',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Ford',
#   'F-150',
#   '2018',
#   '$1,000.00',
#   'na',
#   'na',
#   'Used',
#   'Pickup Truck',
#   'na',
#   'na',
#   'na',
#   '88',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '549 King Street East, Toronto, ON'],
#  ['Pontiac',
#   'Montana',
#   '2006',
#   '$1,100.00',
#   'Silver',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'na',
#   'Automatic',
#   'Gasoline',
#   '147,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Norman Ross Dr, Markham, ON L3S 3E8, Canada'],
#  ['Chrysler',
#   '300-Series',
#   '2011',
#   '$3,400.00',
#   'Black',
#   'LIMITED',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '176,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Etobicoke, ON M9C 1G5'],
#  ['Chevrolet',
#   'Malibu',
#   '2017',
#   '$19,999.00',
#   'Blue',
#   'LTLEATHER|NAVI|PANOROOF|',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '41,432',
#   'https://www.carproof.com/order?ref=kijiji&vin=1G1ZE5ST3HF260990',
#   '2701 Derry Rd. E, Mississauga, ON, L4T 1A2'],
#  ['Honda',
#   'Civic',
#   '2017',
#   '$11,971.00',
#   'White',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '21,196',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFC2F55HH025405',
#   '373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6'],
#  ['Porsche',
#   'Cayenne',
#   '2013',
#   'na',
#   'White',
#   'NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '154,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP1AA2A27DLA06831',
#   '46 Milvan Drive, Toronto, ON, M9L 1Z3'],
#  ['Toyota',
#   'Corolla',
#   '2006',
#   '$2,600.00',
#   'na',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '226',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M4B2E5'],
#  ['Buick',
#   'Enclave',
#   '2012',
#   '$11,988.00',
#   'Silver',
#   '| AWD | 7 PASSENGER | DUAL DVDS',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '132,294',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '1882 Lawrence Avenue East, Scarborough, ON, M1R 2Y5'],
#  ['Tesla',
#   'na',
#   '2016',
#   '$103,995.00',
#   'White',
#   'AutoPilot, 22Whls,SMART Susp, Winters, EV',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Hybrid-Electric',
#   '27,743',
#   'https://reports.carproof.com/en/main?id=W/YxjzzNTHXR6KY36QXfqIayf1IVmYKy&utm_ref=kijiji',
#   '212 Lakeshore Road West, Mississauga, ON, L5H 1G6'],
#  ['Toyota',
#   'RAV4',
#   '2016',
#   '$25,995.00',
#   'Silver',
#   'SE Navigation Leather 18 Alloys',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '78,589',
#   'https://reports.carproof.com/en/main?id=RcRkRH1ls9W1PvoY3Je4 Ao6DVslmPzx&utm_ref=kijiji',
#   '1077 Leslie Street, Toronto, ON, M3C 2J7'],
#  ['Nissan',
#   'Sentra',
#   '2015',
#   '$11,950.00',
#   'Grey',
#   'na',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '82,000',
#   'https://reports.carproof.com/en/main?id=ZM6CIBm/20eDrPkHueZtogcsR1TQgRqN&utm_ref=kijiji',
#   '1205 Finch Avenue West, Toronto, ON, M3J 2E8'],
#  ['Toyota',
#   'Venza',
#   '2012',
#   'na',
#   'Other',
#   'na',
#   'Used',
#   'SUV, Crossover',
#   'Other',
#   'Automatic',
#   'na',
#   '122,203',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '4249 Kingston Road, Scarborough, ON, M1E 2M5'],
#  ['Kia',
#   'Rondo',
#   '2010',
#   'na',
#   'Silver',
#   'na',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   'N/A',
# ...
#   'Other',
#   'Gasoline',
#   '239,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=JN8AS5MV3AW118113',
#   '291 Old Kingston Rd, Scarborough, ON, M1C 1B5'],
#  ['Dodge',
#   'Charger',
#   '2010',
#   'na',
#   'Silver',
#   'SE,RWD,no accident',
#   'Used',
#   'Sedan',
#   'Rear-wheel drive (RWD)',
#   'Automatic',
#   'Gasoline',
#   '185,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=2B3CA4CD7AH112860',
#   '291 Old Kingston Rd, Scarborough, ON, M1C 1B5'],
#  ['Toyota',
#   'Camry',
#   '2014',
#   '$12,988.00',
#   'Grey',
#   'LE-BLUETOOTH-BACK UP CAMERA-ONLY 81KM',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '81,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=4T1BF1FK3EU351244',
#   '301 Weston Road, Toronto, ON, M6N3P1'],
#  ['Nissan',
#   'Quest',
#   '2006',
#   '$2,999.00',
#   'Blue',
#   'na',
#   'Used',
#   'Minivan, Van',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '150,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '1614 Military Trail, Toronto, ON, M1C1B2'],
#  ['Toyota',
#   'Yaris',
#   '2009',
#   '$5,999.00',
#   'Silver',
#   'LE',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '113,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=JTDKT923095273855',
#   'Scarborough, ON M1H 2Z8'],
#  ['Honda',
#   'Element',
#   '2006',
#   '$4,500.00',
#   'na',
#   'EX',
#   'Used',
#   'SUV, Crossover',
#   '4 x 4',
#   'Automatic',
#   'na',
#   '305,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Scarborough, ON M1P 2K9'],
#  ['Hyundai',
#   'Elantra',
#   '2014',
#   '$9,500.00',
#   'Green',
#   'GL',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '53,019',
#   'https://www.carproof.com/order?ref=kijiji&vin=KMHD25LH5EU226590',
#   'Scarborough, ON M1L 4J5'],
#  ['Volkswagen',
#   'Jetta',
#   '2013',
#   '$7,999.00',
#   'Blue',
#   'Comfortline',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '120,017',
#   'https://www.carproof.com/order?ref=kijiji&vin=3VW2K7AJ7DM267946',
#   '55 Toro Rd, North York, ON'],
#  ['Mercedes-Benz',
#   'S-Class',
#   '2008',
#   '$12,800.00',
#   'Black',
#   'S.450.AWD V.8 engine Economic',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '202,300',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Danforth Avenue, Toronto, ON'],
#  ['Honda',
#   'Odyssey',
#   '2006',
#   '$3,400.00',
#   'na',
#   'EXL',
#   'Used',
#   'Minivan, Van',
#   'na',
#   'Automatic',
#   'na',
#   '213,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M5S 1N5'],
#  ['Honda',
#   'Civic',
#   '2012',
#   '$6,995.00',
#   'Black',
#   'LX',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '189,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=2HGFB2F41CH121308',
#   '56 Martin Ross Ave., North York, ON, M3J 2L4'],
#  ['Honda',
#   'Accord',
#   '2015',
#   '$19,995.00',
#   'Black',
#   'Touring',
#   'Used',
#   'Other',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'Gasoline',
#   '75,076',
#   'https://www.carproof.com/order?ref=kijiji&vin=1HGCR2F92FA807340',
#   '1630 Matheson Boulevard, Mississauga, ON, L4W 1Y4'],
#  ['Nissan',
#   'Pathfinder',
#   '2005',
#   '$5,800.00',
#   'Grey',
#   'SE',
#   'Used',
#   'SUV, Crossover',
#   '4 x 4',
#   'Automatic',
#   'na',
#   '173,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=5N1AR18W55C705189',
#   '2310 Sheppard Avenue West, North York, ON, M9M 1M2'],
#  ['Mazda',
#   'Mazda3',
#   '2015',
#   '$12,988.00',
#   'Black',
#   'GS | Sunroof | Back Cam | Heated Seats | Bluetooth',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '101,759',
#   'https://reports.carproof.com/en/main?id=kuC9t5/XjkrN4VsumiRfJ9rA7ExNTFla&utm_ref=kijiji',
#   '5500 Finch Avenue East, Scarborough, ON, M1S 0C7'],
#  ['Nissan',
#   'Rogue',
#   '2010',
#   'na',
#   'Silver',
#   'S,AWD,no accident ,4cyl',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Other',
#   'Gasoline',
#   '239,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=JN8AS5MV3AW118113',
#   '291 Old Kingston Rd, Scarborough, ON, M1C 1B5'],
#  ['Dodge',
#   'Charger',
#   '2010',
#   'na',
#   'Silver',
#   'SE,RWD,no accident',
#   'Used',
#   'Sedan',
#   'Rear-wheel drive (RWD)',
#   'Automatic',
#   'Gasoline',
#   '185,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=2B3CA4CD7AH112860',
#   '291 Old Kingston Rd, Scarborough, ON, M1C 1B5'],
#  ['Nissan',
#   'Quest',
#   '2006',
#   '$2,999.00',
#   'Blue',
#   'na',
#   'Used',
#   'Minivan, Van',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '150,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '1614 Military Trail, Toronto, ON, M1C1B2'],
#  ['Toyota',
#   'Yaris',
#   '2009',
#   '$5,999.00',
#   'Silver',
#   'LE',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '113,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=JTDKT923095273855',
#   'Scarborough, ON M1H 2Z8'],
#  ['Honda',
#   'Element',
#   '2006',
#   '$4,500.00',
#   'na',
#   'EX',
#   'Used',
#   'SUV, Crossover',
#   '4 x 4',
#   'Automatic',
#   'na',
#   '305,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Scarborough, ON M1P 2K9'],
#  ['Hyundai',
#   'Elantra',
#   '2014',
#   '$9,500.00',
#   'Green',
#   'GL',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '53,019',
#   'https://www.carproof.com/order?ref=kijiji&vin=KMHD25LH5EU226590',
#   'Scarborough, ON M1L 4J5'],
#  ['Volkswagen',
#   'Jetta',
#   '2013',
#   '$7,999.00',
#   'Blue',
#   'Comfortline',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '120,017',
#   'https://www.carproof.com/order?ref=kijiji&vin=3VW2K7AJ7DM267946',
#   '55 Toro Rd, North York, ON'],
#  ['Mercedes-Benz',
#   'S-Class',
#   '2008',
#   '$12,800.00',
#   'Black',
#   'S.450.AWD V.8 engine Economic',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '202,300',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Danforth Avenue, Toronto, ON'],
#  ['Honda',
#   'Odyssey',
#   '2006',
#   '$3,400.00',
#   'na',
#   'EXL',
#   'Used',
#   'Minivan, Van',
#   'na',
#   'Automatic',
#   'na',
#   '213,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M5S 1N5'],
#  ['Porsche',
#   'Panamera',
#   '2012',
#   '$47,800.00',
#   'Silver',
#   '4S, 400HP AWD, NAVI,',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '79,989',
#   'https://www.carproof.com/order?ref=kijiji&vin=WP0AB2A73CL061576',
#   '60 Martin Ross Avenue, Toronto, ON, M3J 2L4'],
#  ['GMC',
#   'Savana',
#   '2017',
#   '$26,498.00',
#   'White',
#   "135'' Wheelbase VERY CLEAN FORMER DAILY RENTAL WIT",
#   'Used',
#   'Minivan, Van',
#   'Rear-wheel drive (RWD)',
#   'Automatic',
#   'Gasoline',
#   '14,889',
#   'https://www.carproof.com/order?ref=kijiji&vin=1GTW7AFF5H1285940',
#   '500 Divison st, Windsor, ON, N8X5C4'],
#  ['Volkswagen',
#   'Passat',
#   '2015',
#   '$12,500.00',
#   'Grey',
#   '1.8 TSI TRENDLINE AUT0 A/C CRUISE H/SEATS 96K',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'na',
#   '96,868',
#   'https://reports.carproof.com/en/main?id=pDpjWJEk3suvAfjJNWRl/zDlOljjtSYv&utm_ref=kijiji',
#   '1235 Finch Ave. W., Toronto, ON, M3J 2G4'],
#  ['Mercedes-Benz',
#   'S-Class',
#   '2007',
#   '$12,000.00',
#   'Grey',
#   'na',
#   'Used',
#   'Sedan',
#   'na',
#   'Automatic',
#   'na',
#   '220,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Oakville, ON L6H1J1'],
#  ['Nissan',
#   'Rogue',
#   '2010',
#   'na',
#   'Silver',
#   'S,AWD,no accident ,4cyl',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Other',
#   'Gasoline',
#   '239,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=JN8AS5MV3AW118113',
#   '291 Old Kingston Rd, Scarborough, ON, M1C 1B5'],
#  ['Dodge',
#   'Charger',
#   '2010',
#   'na',
#   'Silver',
#   'SE,RWD,no accident',
#   'Used',
#   'Sedan',
#   'Rear-wheel drive (RWD)',
#   'Automatic',
#   'Gasoline',
#   '185,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=2B3CA4CD7AH112860',
#   '291 Old Kingston Rd, Scarborough, ON, M1C 1B5'],
#  ['Toyota',
#   'Camry',
#   '2014',
#   '$12,988.00',
#   'Grey',
#   'LE-BLUETOOTH-BACK UP CAMERA-ONLY 81KM',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '81,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=4T1BF1FK3EU351244',
#   '301 Weston Road, Toronto, ON, M6N3P1'],
#  ['Nissan',
#   'Quest',
#   '2006',
#   '$2,999.00',
#   'Blue',
#   'na',
#   'Used',
#   'Minivan, Van',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '150,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '1614 Military Trail, Toronto, ON, M1C1B2'],
#  ['Toyota',
#   'Yaris',
#   '2009',
#   '$5,999.00',
#   'Silver',
#   'LE',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '113,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=JTDKT923095273855',
#   'Scarborough, ON M1H 2Z8'],
#  ['Honda',
#   'Element',
#   '2006',
#   '$4,500.00',
#   'na',
#   'EX',
#   'Used',
#   'SUV, Crossover',
#   '4 x 4',
#   'Automatic',
#   'na',
#   '305,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Scarborough, ON M1P 2K9'],
#  ['Hyundai',
#   'Elantra',
#   '2014',
#   '$9,500.00',
#   'Green',
#   'GL',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '53,019',
#   'https://www.carproof.com/order?ref=kijiji&vin=KMHD25LH5EU226590',
#   'Scarborough, ON M1L 4J5'],
#  ['Volkswagen',
#   'Jetta',
#   '2013',
#   '$7,999.00',
#   'Blue',
#   'Comfortline',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '120,017',
#   'https://www.carproof.com/order?ref=kijiji&vin=3VW2K7AJ7DM267946',
#   '55 Toro Rd, North York, ON'],
#  ['Mercedes-Benz',
#   'S-Class',
#   '2008',
#   '$12,800.00',
#   'Black',
#   'S.450.AWD V.8 engine Economic',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '202,300',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Danforth Avenue, Toronto, ON'],
#  ['Honda',
#   'Odyssey',
#   '2006',
#   '$3,400.00',
#   'na',
#   'EXL',
#   'Used',
#   'Minivan, Van',
#   'na',
#   'Automatic',
#   'na',
#   '213,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M5S 1N5'],
#  ['Nissan',
#   'Sentra',
#   '2014',
#   '$9,950.00',
#   'Black',
#   'na',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Other',
#   'na',
#   '119,000',
#   'https://reports.carproof.com/en/main?id=tKMYi7MlvmObu tdjmXGKAZv1UKQNnHl&utm_ref=kijiji',
#   '1205 Finch Avenue West, Toronto, ON, M3J 2E8'],
#  ['Hyundai',
#   'Santa Fe',
#   '2018',
#   '$50,828.00',
#   'Other',
#   'Ultimate 6 Passenger',
#   'New',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   'na',
#   'na',
#   '785 Woodlawn Road West, Guelph, ON, N1K 1E9'],
#  ['Genesis',
#   'Other',
#   '2019',
#   '$41,900.00',
#   'Blue',
#   '2.0T ELITE|AWD |NAVI|LEATHER|ROOF|BCAM',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '12,365',
#   'https://www.carproof.com/order?ref=kijiji&vin=KMTG64LA7KU008506',
#   '2730 Markham Road, Scarborough, ON, M1X 1E6'],
#  ['Chevrolet',
#   'Tahoe',
#   '2015',
#   '$40,988.00',
#   'Other',
#   'LT',
#   'Used',
#   'Other',
#   '4 x 4',
#   'Automatic',
#   'Gasoline',
#   '97,157',
#   'https://reports.carproof.com/en/main?id=JlxJYXOlIAcpWIhpAiCXUKkyARiAI1yE&utm_ref=kijiji',
#   '1900 Victoria Park Avenue, Toronto, ON, M1R 1T6'],
#  ['Nissan',
#   'Rogue',
#   '2010',
#   'na',
#   'Silver',
#   'S,AWD,no accident ,4cyl',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Other',
#   'Gasoline',
#   '239,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=JN8AS5MV3AW118113',
#   '291 Old Kingston Rd, Scarborough, ON, M1C 1B5'],
#  ['Dodge',
#   'Charger',
#   '2010',
#   'na',
#   'Silver',
#   'SE,RWD,no accident',
#   'Used',
#   'Sedan',
#   'Rear-wheel drive (RWD)',
#   'Automatic',
#   'Gasoline',
#   '185,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=2B3CA4CD7AH112860',
#   '291 Old Kingston Rd, Scarborough, ON, M1C 1B5'],
#  ['Toyota',
#   'Camry',
#   '2014',
#   '$12,988.00',
#   'Grey',
#   'LE-BLUETOOTH-BACK UP CAMERA-ONLY 81KM',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '81,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=4T1BF1FK3EU351244',
#   '301 Weston Road, Toronto, ON, M6N3P1'],
#  ['Nissan',
#   'Quest',
#   '2006',
#   '$2,999.00',
#   'Blue',
#   'na',
#   'Used',
#   'Minivan, Van',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '150,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   '1614 Military Trail, Toronto, ON, M1C1B2'],
#  ['Toyota',
#   'Yaris',
#   '2009',
#   '$5,999.00',
#   'Silver',
#   'LE',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '113,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=JTDKT923095273855',
#   'Scarborough, ON M1H 2Z8'],
#  ['Honda',
#   'Element',
#   '2006',
#   '$4,500.00',
#   'na',
#   'EX',
#   'Used',
#   'SUV, Crossover',
#   '4 x 4',
#   'Automatic',
#   'na',
#   '305,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Scarborough, ON M1P 2K9'],
#  ['Hyundai',
#   'Elantra',
#   '2014',
#   '$9,500.00',
#   'Green',
#   'GL',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '53,019',
#   'https://www.carproof.com/order?ref=kijiji&vin=KMHD25LH5EU226590',
#   'Scarborough, ON M1L 4J5'],
#  ['Volkswagen',
#   'Jetta',
#   '2013',
#   '$7,999.00',
#   'Blue',
#   'Comfortline',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '120,017',
#   'https://www.carproof.com/order?ref=kijiji&vin=3VW2K7AJ7DM267946',
#   '55 Toro Rd, North York, ON'],
#  ['Mercedes-Benz',
#   'S-Class',
#   '2008',
#   '$12,800.00',
#   'Black',
#   'S.450.AWD V.8 engine Economic',
#   'Used',
#   'Sedan',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '202,300',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Danforth Avenue, Toronto, ON'],
#  ['Honda',
#   'Odyssey',
#   '2006',
#   '$3,400.00',
#   'na',
#   'EXL',
#   'Used',
#   'Minivan, Van',
#   'na',
#   'Automatic',
#   'na',
#   '213,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=null',
#   'Toronto, ON M5S 1N5'],
#  ['Volkswagen',
#   'Jetta',
#   '2013',
#   '$9,900.00',
#   'White',
#   'Highline',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '92,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=3VWLX7AJ2DM356815',
#   '1830 Lawrence Avenue East, Toronto, ON, M1R 2Y2'],
#  ['BMW',
#   'X1',
#   '2015',
#   '$18,950.00',
#   'Grey',
#   'xDrive28i PREMIUM PKG LEATHER PAN SUNROOF AWD',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Gasoline',
#   '79,000',
#   'https://reports.carproof.com/en/main?id=OeBtKw0zYdbjcK4QRVQeHq8LGOs8W63R&utm_ref=kijiji',
#   '1205 Finch Avenue West, Toronto, ON, M3J 2E8'],
#  ['BMW',
#   'X1',
#   '2015',
#   '$19,250.00',
#   'White',
#   'XDRIVE AUT0 NAVI LEATHER PANO/ROOF CAMERA 81K',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'na',
#   '81,448',
#   'https://reports.carproof.com/en/main?id=tKYi1MtRFjqHyboE/zAOgERmINA5G4z5&utm_ref=kijiji',
#   '1235 Finch Ave. W., Toronto, ON, M3J 2G4'],
#  ['Audi',
#   'Q7',
#   '2015',
#   '$42,880.00',
#   'Grey',
#   'TDI|VORSPRUNG|B.SPOT|360|NAVI|LDW|LOADED',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Automatic',
#   'Diesel',
#   '56,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=WA1VMCFEXFD002767',
#   '150 Deerhide Crescent, North York, ON, M9M 2Y6'],
#  ['Nissan',
#   'Rogue',
#   '2010',
#   'na',
#   'Silver',
#   'S,AWD,no accident ,4cyl',
#   'Used',
#   'SUV, Crossover',
#   'All-wheel drive (AWD)',
#   'Other',
#   'Gasoline',
#   '239,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=JN8AS5MV3AW118113',
#   '291 Old Kingston Rd, Scarborough, ON, M1C 1B5'],
#  ['Dodge',
#   'Charger',
#   '2010',
#   'na',
#   'Silver',
#   'SE,RWD,no accident',
#   'Used',
#   'Sedan',
#   'Rear-wheel drive (RWD)',
#   'Automatic',
#   'Gasoline',
#   '185,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=2B3CA4CD7AH112860',
#   '291 Old Kingston Rd, Scarborough, ON, M1C 1B5'],
#  ['Toyota',
#   'Camry',
#   '2014',
#   '$12,988.00',
#   'Grey',
#   'LE-BLUETOOTH-BACK UP CAMERA-ONLY 81KM',
#   'Used',
#   'Sedan',
#   'Front-wheel drive (FWD)',
#   'Automatic',
#   'Gasoline',
#   '81,000',
#   'https://www.carproof.com/order?ref=kijiji&vin=4T1BF1FK3EU351244',
#   '301 Weston Road, Toronto, ON, M6N3P1'],
#  ...]

# %%
df = pd.DataFrame(all_info_list)

# %% [markdown]
# # Transformation
#
# ## Transform all information into pandas dataframe

# %%
df
# Out:
#                  0               1     2           3         4   \
# 0         Chevrolet  Silverado 1500  2017  $30,999.99     Black
# 1        Volkswagen          Tiguan  2013  $11,450.00      Grey
# 2               GMC          Acadia  2017  $33,988.00     Other
# 3             Acura              TL  2002     $500.00        na
# 4             Honda          Accord  2015  $15,499.00     White
# 5           Pontiac         Montana  2006   $1,100.00    Silver
# 6          Chrysler      300-Series  2011   $3,400.00     Black
# 7         Chevrolet          Malibu  2017  $19,999.00      Blue
# 8             Honda           Civic  2017  $11,971.00     White
# 9           Porsche         Cayenne  2013          na     White
# 10           Toyota         Corolla  2006   $2,600.00        na
# 11             Ford          Escape  2015  $15,988.00     White
# 12         Cadillac         DeVille  2001   $1,000.00  Burgundy
# 13             Ford            Edge  2018  $43,578.00    Silver
# 14           Toyota           Other  2012  $11,500.00        na
# 15              BMW        3-Series  2014  $21,500.00       Red
# 16            Tesla              na  2015  $93,995.00      Blue
# 17           Toyota            RAV4  2014  $15,950.00      Grey
# 18            Honda           Civic  2016  $21,877.00     White
# 19          Pontiac         Montana  2006   $1,100.00    Silver
# 20         Chrysler      300-Series  2011   $3,400.00     Black
# 21        Chevrolet          Malibu  2017  $19,999.00      Blue
# 22            Honda           Civic  2017  $11,971.00     White
# 23          Porsche         Cayenne  2013          na     White
# 24           Toyota         Corolla  2006   $2,600.00        na
# 25             Ford          Escape  2015  $15,988.00     White
# 26         Cadillac         DeVille  2001   $1,000.00  Burgundy
# 27            Honda          Accord  2014  $16,950.00      Grey
# 28            Honda           Other  2006   $1,190.00       Red
# 29          Porsche         Cayenne  2013  $53,988.00     White
# ...             ...             ...   ...         ...       ...
# 3975           Fiat             500  2014  $12,800.00     Other
# 3976           Audi              S5  2013  $35,800.00     Black
# 3977          Mazda          Mazda3  2015   $9,999.00      Grey
# 3978         Jaguar           Other  2017  $87,990.00     White
# 3979         Nissan          Sentra  2015  $13,999.00     White
# 3980     Volkswagen           Jetta  2015   $9,500.00     White
# 3981  Mercedes-Benz         M-Class  2015  $35,999.00      Grey
# 3982      Chevrolet        Uplander  2008   $3,899.00      Blue
# 3983        Pontiac        Grand Am  2000          na      Gold
# 3984         Toyota         Corolla  2004          na      Grey
# 3985          Acura             MDX  2016  $33,182.00    Silver
# 3986      Chevrolet           Sonic  2020     $298.00     White
# 3987            Kia             Rio  2009   $3,999.00     White
# 3988      Chevrolet         Equinox  2019  $39,160.00     Black
# 3989      Chevrolet        Traverse  2019  $43,050.00     White
# 3990            GMC     Sierra 1500  2010   $3,700.00     Black
# 3991      Chevrolet        Traverse  2019  $38,645.00     Black
# 3992           Jeep        Wrangler  2019  $64,010.00       Red
# 3993         Nissan          Altima  2006   $3,475.00      Blue
# 3994          Honda           Pilot  2004   $2,999.00    Silver
# 3995     Volkswagen            Golf  2013   $8,888.00      Gold
# 3996     Volkswagen           Jetta  2015  $13,990.00     Black
# 3997          Honda           Civic  2013  $14,450.00     Black
# 3998      Chevrolet        Uplander  2008   $3,899.00      Blue
# 3999        Pontiac        Grand Am  2000          na      Gold
# 4000         Toyota         Corolla  2004          na      Grey
# 4001          Acura             MDX  2016  $33,182.00    Silver
# 4002      Chevrolet           Sonic  2020     $298.00     White
# 4003            Kia             Rio  2009   $3,999.00     White
# 4004      Chevrolet         Equinox  2019  $39,160.00     Black
#
#                                                      5               6   \
# 0                                                    LT            Used
# 1                                      COMFORTLINE  4WD            Used
# 2                                                 SLT-2            Used
# 3                                                    na            Used
# 4                                                    LX            Used
# 5                                                    na            Used
# 6                                               LIMITED            Used
# 7                              LTLEATHER|NAVI|PANOROOF|            Used
# 8                                                    LX            Used
# 9       NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!            Used
# 10                                                   na            Used
# 11       SE, $62/wk, heated seat, alloys, backup camera            Used
# 12                                                  DHS            Used
# 13      1 OWNER, Accident Free, Navi, Heated Seats, AWD            Used
# 14                                                   LE            Used
# 15       320I X DRIVE SPORT+ NAVI PKG AUT0 SUNROOF 103K            Used
# 16          Autopilot, 21Whls, Sunroof, INSANE Mode, EV            Used
# 17                                               LE AWD            Used
# 18         EX-T w/Honda Sensing/SUNROOF/REAR CAMERA !!!            Used
# 19                                                   na            Used
# 20                                              LIMITED            Used
# 21                             LTLEATHER|NAVI|PANOROOF|            Used
# 22                                                   LX            Used
# 23      NAVIGATION SYSTEM/HEATED SEATS/HEATED STEERING!            Used
# 24                                                   na            Used
# 25       SE, $62/wk, heated seat, alloys, backup camera            Used
# 26                                                  DHS            Used
# 27    TOURING NAVIGATION LEATHER SUNROOF BACK UP CAMERA            Used
# 28                       LIKE NEW!!/CHRISTMAS SPECIAL!!            Used
# 29       GTS/NAV/PORSCHE ENTRY&DRIVE/LANE CHANGE ASSIST            Used
# ...                                                 ...             ...
# 3975                               ABARTH, 5 SPEED, SUN            Used
# 3976                                4.2 QUATTRO, 450HP,            Used
# 3977        Special Price Offer For GX MODEL, SKYACTIVE            Used
# 3978                    Coupe R 550HP!! Active Exhaust!            Used
# 3979       SL MODEL, LEATHER SEATS, SUNROOF, NAVIGATION            Used
# 3980  2.0L TRENDLINE 5 SPEED A/C H/SEATS REAR CAMERA...            Used
# 3981                  ML 350 BlueTEC 4MATIC NAVIGATION,            Used
# 3982                                                EXT            Used
# 3983                                                 na            Used
# 3984                                                 na            Used
# 3985     Navi 7yrs/130,000K Certified Warranty Inlcuded            Used
# 3986                                                 LT  Lease Takeover
# 3987          Rio5 EX Sport/Safety/ETest included Price            Used
# 3988                                                 LT             New
# 3989                                           LT Cloth             New
# 3990    4X4 4.8L V8 Regular Cab 8Ft Box "AS IS" Special            Used
# 3991                                                 LS             New
# 3992                                            Rubicon             New
# 3993                           2.5 S P.group, Certified            Used
# 3994                                                 na            Used
# 3995                    TDI | WAGON | PANOROOF | DIESEL            Used
# 3996    2.0L TRENDLINE AUT0 A/C H/SEATS REAR CAMERA 49K            Used
# 3997  TOURING PKG NAVIGATION LEATHER SUNROOF BACK UP...            Used
# 3998                                                EXT            Used
# 3999                                                 na            Used
# 4000                                                 na            Used
# 4001     Navi 7yrs/130,000K Certified Warranty Inlcuded            Used
# 4002                                                 LT  Lease Takeover
# 4003          Rio5 EX Sport/Safety/ETest included Price            Used
# 4004                                                 LT             New
#
#                   7                        8          9                10  \
# 0       Pickup Truck                    4 x 4  Automatic         Gasoline
# 1     SUV, Crossover    All-wheel drive (AWD)  Automatic         Gasoline
# 2              Other    All-wheel drive (AWD)  Automatic         Gasoline
# 3              Sedan                       na         na               na
# 4              Sedan  Front-wheel drive (FWD)      Other         Gasoline
# 5     SUV, Crossover                       na  Automatic         Gasoline
# 6              Sedan    All-wheel drive (AWD)  Automatic         Gasoline
# 7              Sedan  Front-wheel drive (FWD)  Automatic               na
# 8              Sedan  Front-wheel drive (FWD)      Other         Gasoline
# 9     SUV, Crossover    All-wheel drive (AWD)  Automatic         Gasoline
# 10             Sedan                       na  Automatic               na
# 11    SUV, Crossover                    Other  Automatic         Gasoline
# 12             Sedan  Front-wheel drive (FWD)  Automatic         Gasoline
# 13    SUV, Crossover    All-wheel drive (AWD)  Automatic         Gasoline
# 14             Sedan  Front-wheel drive (FWD)  Automatic  Hybrid-Electric
# 15             Sedan    All-wheel drive (AWD)  Automatic         Gasoline
# 16             Sedan    All-wheel drive (AWD)  Automatic  Hybrid-Electric
# 17    SUV, Crossover    All-wheel drive (AWD)  Automatic               na
# 18    Coupe (2 door)  Front-wheel drive (FWD)  Automatic               na
# 19    SUV, Crossover                       na  Automatic         Gasoline
# 20             Sedan    All-wheel drive (AWD)  Automatic         Gasoline
# 21             Sedan  Front-wheel drive (FWD)  Automatic               na
# 22             Sedan  Front-wheel drive (FWD)      Other         Gasoline
# 23    SUV, Crossover    All-wheel drive (AWD)  Automatic         Gasoline
# 24             Sedan                       na  Automatic               na
# 25    SUV, Crossover                    Other  Automatic         Gasoline
# 26             Sedan  Front-wheel drive (FWD)  Automatic         Gasoline
# 27             Sedan  Front-wheel drive (FWD)      Other         Gasoline
# 28             Sedan                    Other      Other         Gasoline
# 29    SUV, Crossover    All-wheel drive (AWD)  Automatic               na
# ...              ...                      ...        ...              ...
# 3975       Hatchback  Front-wheel drive (FWD)     Manual               na
# 3976  Coupe (2 door)    All-wheel drive (AWD)  Automatic               na
# 3977           Sedan  Front-wheel drive (FWD)     Manual         Gasoline
# 3978           Sedan    All-wheel drive (AWD)  Automatic         Gasoline
# 3979           Sedan  Front-wheel drive (FWD)      Other         Gasoline
# 3980           Sedan  Front-wheel drive (FWD)     Manual               na
# 3981  SUV, Crossover                    Other  Automatic         Gasoline
# 3982    Minivan, Van  Front-wheel drive (FWD)  Automatic         Gasoline
# 3983           Sedan                       na         na               na
# 3984           Sedan  Front-wheel drive (FWD)  Automatic         Gasoline
# 3985  SUV, Crossover                    Other  Automatic               na
# 3986       Hatchback  Front-wheel drive (FWD)  Automatic               na
# 3987           Sedan  Front-wheel drive (FWD)  Automatic         Gasoline
# 3988           Wagon    All-wheel drive (AWD)  Automatic         Gasoline
# 3989           Wagon  Front-wheel drive (FWD)  Automatic         Gasoline
# 3990    Pickup Truck                    4 x 4  Automatic         Gasoline
# 3991           Wagon  Front-wheel drive (FWD)  Automatic         Gasoline
# 3992  SUV, Crossover    All-wheel drive (AWD)     Manual               na
# 3993           Sedan  Front-wheel drive (FWD)  Automatic         Gasoline
# 3994  SUV, Crossover    All-wheel drive (AWD)  Automatic               na
# 3995           Sedan  Front-wheel drive (FWD)  Automatic           Diesel
# 3996           Sedan  Front-wheel drive (FWD)  Automatic         Gasoline
# 3997           Sedan  Front-wheel drive (FWD)  Automatic               na
# 3998    Minivan, Van  Front-wheel drive (FWD)  Automatic         Gasoline
# 3999           Sedan                       na         na               na
# 4000           Sedan  Front-wheel drive (FWD)  Automatic         Gasoline
# 4001  SUV, Crossover                    Other  Automatic               na
# 4002       Hatchback  Front-wheel drive (FWD)  Automatic               na
# 4003           Sedan  Front-wheel drive (FWD)  Automatic         Gasoline
# 4004           Wagon    All-wheel drive (AWD)  Automatic         Gasoline
#
#            11                                                 12  \
# 0     115,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 1     129,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 2      73,893  https://reports.carproof.com/en/main?id=ioaVnM...
# 3     200,500  https://www.carproof.com/order?ref=kijiji&vin=...
# 4      93,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 5     147,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 6     176,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 7      41,432  https://www.carproof.com/order?ref=kijiji&vin=...
# 8      21,196  https://www.carproof.com/order?ref=kijiji&vin=...
# 9     154,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 10        226  https://www.carproof.com/order?ref=kijiji&vin=...
# 11     74,899  https://www.carproof.com/order?ref=kijiji&vin=...
# 12    200,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 13     11,618  https://www.carproof.com/order?ref=kijiji&vin=...
# 14    156,988  https://www.carproof.com/order?ref=kijiji&vin=...
# 15    103,558  https://www.carproof.com/order?ref=kijiji&vin=...
# 16     27,981  https://reports.carproof.com/en/main?id=ig5IdG...
# 17    131,000  https://reports.carproof.com/en/main?id=DCWc4i...
# 18     30,345  https://www.carproof.com/order?ref=kijiji&vin=...
# 19    147,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 20    176,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 21     41,432  https://www.carproof.com/order?ref=kijiji&vin=...
# 22     21,196  https://www.carproof.com/order?ref=kijiji&vin=...
# 23    154,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 24        226  https://www.carproof.com/order?ref=kijiji&vin=...
# 25     74,899  https://www.carproof.com/order?ref=kijiji&vin=...
# 26    200,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 27    123,000  https://reports.carproof.com/en/main?id=34OnNI...
# 28        513  https://www.carproof.com/order?ref=kijiji&vin=...
# 29     69,000  https://www.carproof.com/order?ref=kijiji&vin=...
# ...       ...                                                ...
# 3975   76,906  https://www.carproof.com/order?ref=kijiji&vin=...
# 3976  136,200  https://www.carproof.com/order?ref=kijiji&vin=...
# 3977   71,918  https://www.carproof.com/order?ref=kijiji&vin=...
# 3978   48,784  https://www.carproof.com/order?ref=kijiji&vin=...
# 3979   75,203  https://www.carproof.com/order?ref=kijiji&vin=...
# 3980   67,069  https://reports.carproof.com/en/main?id=IwjEf/...
# 3981   62,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 3982  150,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 3983  350,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 3984  505,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 3985   44,660  https://www.carproof.com/order?ref=kijiji&vin=...
# 3986   20,800  https://www.carproof.com/order?ref=kijiji&vin=...
# 3987  115,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 3988       na                                                 na
# 3989       na                                                 na
# 3990  314,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 3991       na                                                 na
# 3992       na                                                 na
# 3993  172,485  https://www.carproof.com/order?ref=kijiji&vin=...
# 3994  161,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 3995  149,683  https://www.carproof.com/order?ref=kijiji&vin=...
# 3996   49,353  https://www.carproof.com/order?ref=kijiji&vin=...
# 3997   85,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 3998  150,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 3999  350,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 4000  505,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 4001   44,660  https://www.carproof.com/order?ref=kijiji&vin=...
# 4002   20,800  https://www.carproof.com/order?ref=kijiji&vin=...
# 4003  115,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 4004       na                                                 na
#
#                                                      13
# 0                           Brydon Drive, Etobicoke, ON
# 1          1205 Finch Avenue West, Toronto, ON, M3J 2E8
# 2       1900 Victoria Park Avenue, Toronto, ON, M1R 1T6
# 3                                    Toronto, ON M5N1A1
# 4          1726 Kingston Road, Scarborough, ON, M1N 1S8
# 5           Norman Ross Dr, Markham, ON L3S 3E8, Canada
# 6                                 Etobicoke, ON M9C 1G5
# 7            2701 Derry Rd. E, Mississauga, ON, L4T 1A2
# 8       373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6
# 9                 46 Milvan Drive, Toronto, ON, M9L 1Z3
# 10                                   Toronto, ON M4B2E5
# 11      4700 Sheppard Avenue East, Toronto, ON, M1S 3V6
# 12                               Woodbridge, ON L4L 8L6
# 13    2595 Saint Clair Avenue West, Toronto, ON, M6N...
# 14                                   Toronto, ON M1X0B1
# 15             1235 Finch Ave. W., Toronto, ON, M3J 2G4
# 16    212 Lakeshore Road West, Mississauga, ON, L5H 1G6
# 17         1205 Finch Avenue West, Toronto, ON, M3J 2E8
# 18            2685 Highway 7 West, Concord, ON, L4K 1V8
# 19          Norman Ross Dr, Markham, ON L3S 3E8, Canada
# 20                                Etobicoke, ON M9C 1G5
# 21           2701 Derry Rd. E, Mississauga, ON, L4T 1A2
# 22      373 Danforth Rd,  ON, Scarborough,, ON, M1L 3X6
# 23                46 Milvan Drive, Toronto, ON, M9L 1Z3
# 24                                   Toronto, ON M4B2E5
# 25      4700 Sheppard Avenue East, Toronto, ON, M1S 3V6
# 26                               Woodbridge, ON L4L 8L6
# 27         1205 Finch Avenue West, Toronto, ON, M3J 2E8
# 28               4 Harvest Street, Lindsay, ON, K9V 4W9
# 29                46 Milvan Drive, Toronto, ON, M9L 1Z3
# ...                                                 ...
# 3975        60 Martin Ross Avenue, Toronto, ON, M3J 2L4
# 3976        60 Martin Ross Avenue, Toronto, ON, M3J 2L4
# 3977            3675 Keele Street, Toronto, ON, M3J 1M6
# 3978      123 Auto Park Circle, Woodbridge, ON, L4L 8R1
# 3979            3675 Keele Street, Toronto, ON, M3J 1M6
# 3980           1235 Finch Ave. W., Toronto, ON, M3J 2G4
# 3981  1100 Finch Avenue West, Unit 11D, North York, ...
# 3982                              Etobicoke, ON M9W 7J4
# 3983                                 Toronto, ON M9L1R2
# 3984                                    Vaughan, ON L4L
# 3985          7064 Yonge Street, Thornhill, ON, L4J 1V7
# 3986                                 Toronto, ON M1P5E4
# 3987           3406 Kingston Road, Toronto, ON, M1M 1R2
# 3988         3180 Dufferin Street, Toronto, ON, M6A 2T1
# 3989         3180 Dufferin Street, Toronto, ON, M6A 2T1
# 3990       1065 Martin Grove Road, Toronto, ON, M9W 4W6
# 3991         3180 Dufferin Street, Toronto, ON, M6A 2T1
# 3992         17615 Yonge Street, Newmarket, ON, L3Y 5H6
# 3993       6470 Kingston Road, Scarborough, ON, M1C 1L4
# 3994     3891 Keele St, Unit B, North York, ON, M3J 1N6
# 3995  1882 Lawrence Avenue East, Scarborough, ON, M1...
# 3996           1235 Finch Ave. W., Toronto, ON, M3J 2G4
# 3997       1205 Finch Avenue West, Toronto, ON, M3J 2E8
# 3998                              Etobicoke, ON M9W 7J4
# 3999                                 Toronto, ON M9L1R2
# 4000                                    Vaughan, ON L4L
# 4001          7064 Yonge Street, Thornhill, ON, L4J 1V7
# 4002                                 Toronto, ON M1P5E4
# 4003           3406 Kingston Road, Toronto, ON, M1M 1R2
# 4004         3180 Dufferin Street, Toronto, ON, M6A 2T1
#
# [4005 rows x 14 columns]

# %%
columns_name = ['brand','model','model_year','list_price','color','configration','condition','body_type',\
               'wheel_config','transmission','fuel_type','mileage','carfax_link','dealer_address']

# %%
df.columns = columns_name

# %%
df.head()
# Out:
#         brand           model model_year  list_price  color      configration  \
# 0   Chevrolet  Silverado 1500       2017  $30,999.99  Black                LT
# 1  Volkswagen          Tiguan       2013  $11,450.00   Grey  COMFORTLINE  4WD
# 2         GMC          Acadia       2017  $33,988.00  Other             SLT-2
# 3       Acura              TL       2002     $500.00     na                na
# 4       Honda          Accord       2015  $15,499.00  White                LX
#
#   condition       body_type             wheel_config transmission fuel_type  \
# 0      Used    Pickup Truck                    4 x 4    Automatic  Gasoline
# 1      Used  SUV, Crossover    All-wheel drive (AWD)    Automatic  Gasoline
# 2      Used           Other    All-wheel drive (AWD)    Automatic  Gasoline
# 3      Used           Sedan                       na           na        na
# 4      Used           Sedan  Front-wheel drive (FWD)        Other  Gasoline
#
#    mileage                                        carfax_link  \
# 0  115,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 1  129,000  https://www.carproof.com/order?ref=kijiji&vin=...
# 2   73,893  https://reports.carproof.com/en/main?id=ioaVnM...
# 3  200,500  https://www.carproof.com/order?ref=kijiji&vin=...
# 4   93,000  https://www.carproof.com/order?ref=kijiji&vin=...
#
#                                     dealer_address
# 0                      Brydon Drive, Etobicoke, ON
# 1     1205 Finch Avenue West, Toronto, ON, M3J 2E8
# 2  1900 Victoria Park Avenue, Toronto, ON, M1R 1T6
# 3                               Toronto, ON M5N1A1
# 4     1726 Kingston Road, Scarborough, ON, M1N 1S8

# %%
df.to_csv('kijiji_car.csv')
